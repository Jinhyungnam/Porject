# %%
# ver04
# image 변주를 주고, smote로 해봄 acc 97.5 f1 95? 나오지만 정말 이상한 데이터들은 못찾음
# filename	answer	비슷	pred	sum	
# 00198.png	18	11,28	11	28	가려진거
# 00829.png	27	30	30	27	절반 그림자
# 00072.png	30	28,31	11	25	흐림
# 01079.png	21	14	41	15	배경다르고 가운데 모양만있음
# 02635.png	5	4	2	13	너무 흐림
# 00033.png	23	31	31	12	안보임
# 00790.png	2	31	3	11	어두움
# 00050.png	25	11	2	9	가려지고 너무흐림
					
					
# 8297					말도안됨
	
# 					가운데만 Crop해보고 시도하고
# 					해상도 올리는걸 Test에도?
# 0601 22 Test data 해상도만 올려서 해보자

# data_transforms_rand = transforms.Compose([
#   transforms.RandomRotation(degrees=15),
#   transforms.RandomAutocontrast(),
#   transforms.RandomAdjustSharpness(4),
#   transforms.Resize([112, 112]),
#   transforms.Pad(10),
#   transforms.ToTensor()
#   # transforms.Normalize(0, 1)
#   ])

# %%
_ = """
+ CutMix 
+ data_aug

"""

# %%
# traffic sign down
# !gdown --id 1ysKr2SJAxGWrdSvoA5fn40jhRQmbPswl
# !gdown --id 1-MsSMJqE8AdMQYgS_tiYiaeTkiF4WB5F
# !unzip data.zip
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  extracting: Test/03670.png
#  extracting: Test/03671.png
#  extracting: Test/03672.png
#  extracting: Test/03673.png
#  extracting: Test/03674.png
#  extracting: Test/03675.png
#  extracting: Test/03676.png
#  extracting: Test/03677.png
#   inflating: Test/03678.png
#  extracting: Test/03679.png
#  extracting: Test/03680.png
#  extracting: Test/03681.png
#  extracting: Test/03682.png
#  extracting: Test/03683.png
#   inflating: Test/03684.png
#  extracting: Test/03685.png
#  extracting: Test/03686.png
#  extracting: Test/03687.png
#  extracting: Test/03688.png
#  extracting: Test/03689.png
#  extracting: Test/03690.png
#  extracting: Test/03691.png
#  extracting: Test/03692.png
#   inflating: Test/03693.png
#  extracting: Test/03694.png
#  extracting: Test/03695.png
#   inflating: Test/03696.png
#  extracting: Test/03697.png
#  extracting: Test/03698.png
#  extracting: Test/03699.png
#  extracting: Test/03700.png
#  extracting: Test/03701.png
#  extracting: Test/03702.png
#  extracting: Test/03703.png
#  extracting: Test/03704.png
#  extracting: Test/03705.png
#  extracting: Test/03706.png
#   inflating: Test/03707.png
#  extracting: Test/03708.png
#  extracting: Test/03709.png
#  extracting: Test/03710.png
#  extracting: Test/03711.png
#  extracting: Test/03712.png
#  extracting: Test/03713.png
#   inflating: Test/03714.png
#  extracting: Test/03715.png
#  extracting: Test/03716.png
#  extracting: Test/03717.png
#  extracting: Test/03718.png
#  extracting: Test/03719.png
#   inflating: Test/03720.png
#  extracting: Test/03721.png
#   inflating: Test/03722.png
#  extracting: Test/03723.png
#  extracting: Test/03724.png
#  extracting: Test/03725.png
#  extracting: Test/03726.png
#   inflating: Test/03727.png
#  extracting: Test/03728.png
#  extracting: Test/03729.png
#  extracting: Test/03730.png
#  extracting: Test/03731.png
#  extracting: Test/03732.png
#  extracting: Test/03733.png
#  extracting: Test/03734.png
#  extracting: Test/03735.png
#  extracting: Test/03736.png
#  extracting: Test/03737.png
#  extracting: Test/03738.png
#  extracting: Test/03739.png
#  extracting: Test/03740.png
#   inflating: Test/03741.png
#   inflating: Test/03742.png
#  extracting: Test/03743.png
#  extracting: Test/03744.png
#  extracting: Test/03745.png
#  extracting: Test/03746.png
#  extracting: Test/03747.png
#  extracting: Test/03748.png
#  extracting: Test/03749.png
#  extracting: Test/03750.png
#  extracting: Test/03751.png
#  extracting: Test/03752.png
#  extracting: Test/03753.png
#  extracting: Test/03754.png
#   inflating: Test/03755.png
#  extracting: Test/03756.png
#  extracting: Test/03757.png
#  extracting: Test/03758.png
#  extracting: Test/03759.png
#  extracting: Test/03760.png
#  extracting: Test/03761.png
#  extracting: Test/03762.png
#  extracting: Test/03763.png
#  extracting: Test/03764.png
#  extracting: Test/03765.png
#  extracting: Test/03766.png
#  extracting: Test/03767.png
#  extracting: Test/03768.png
#  extracting: Test/03769.png
#  extracting: Test/03770.png
#  extracting: Test/03771.png
#  extracting: Test/03772.png
#  extracting: Test/03773.png
#  extracting: Test/03774.png
#  extracting: Test/03775.png
#  extracting: Test/03776.png
#  extracting: Test/03777.png
#  extracting: Test/03778.png
#  extracting: Test/03779.png
#  extracting: Test/03780.png
#  extracting: Test/03781.png
#  extracting: Test/03782.png
#  extracting: Test/03783.png
#  extracting: Test/03784.png
#  extracting: Test/03785.png
#  extracting: Test/03786.png
#  extracting: Test/03787.png
#  extracting: Test/03788.png
#  extracting: Test/03789.png
#   inflating: Test/03790.png
#  extracting: Test/03791.png
#  extracting: Test/03792.png
#  extracting: Test/03793.png
#  extracting: Test/03794.png
#  extracting: Test/03795.png
#  extracting: Test/03796.png
#  extracting: Test/03797.png
#   inflating: Test/03798.png
#   inflating: Test/03799.png
#  extracting: Test/03800.png
#  extracting: Test/03801.png
#  extracting: Test/03802.png
#  extracting: Test/03803.png
#  extracting: Test/03804.png
#  extracting: Test/03805.png
#  extracting: Test/03806.png
#  extracting: Test/03807.png
#  extracting: Test/03808.png
#   inflating: Test/03809.png
#  extracting: Test/03810.png
#   inflating: Test/03811.png
#   inflating: Test/03812.png
#  extracting: Test/03813.png
#  extracting: Test/03814.png
#  extracting: Test/03815.png
#  extracting: Test/03816.png
#  extracting: Test/03817.png
#  extracting: Test/03818.png
#  extracting: Test/03819.png
#  extracting: Test/03820.png
#  extracting: Test/03821.png
#  extracting: Test/03822.png
#  extracting: Test/03823.png
#  extracting: Test/03824.png
#   inflating: Test/03825.png
#  extracting: Test/03826.png
#  extracting: Test/03827.png
#   inflating: Test/03828.png
#  extracting: Test/03829.png
#  extracting: Test/03830.png
#  extracting: Test/03831.png
#  extracting: Test/03832.png
#  extracting: Test/03833.png
#  extracting: Test/03834.png
#  extracting: Test/03835.png
#  extracting: Test/03836.png
#  extracting: Test/03837.png
#  extracting: Test/03838.png
#  extracting: Test/03839.png
#   inflating: Test/03840.png
#  extracting: Test/03841.png
#   inflating: Test/03842.png
#  extracting: Test/03843.png
#  extracting: Test/03844.png
#  extracting: Test/03845.png
#  extracting: Test/03846.png
#  extracting: Test/03847.png
#  extracting: Test/03848.png
#  extracting: Test/03849.png
#  extracting: Test/03850.png
#  extracting: Test/03851.png
#  extracting: Test/03852.png
#  extracting: Test/03853.png
#  extracting: Test/03854.png
#  extracting: Test/03855.png
#  extracting: Test/03856.png
#  extracting: Test/03857.png
#  extracting: Test/03858.png
#  extracting: Test/03859.png
#  extracting: Test/03860.png
#  extracting: Test/03861.png
#   inflating: Test/03862.png
#  extracting: Test/03863.png
#  extracting: Test/03864.png
#  extracting: Test/03865.png
#  extracting: Test/03866.png
#  extracting: Test/03867.png
#  extracting: Test/03868.png
#  extracting: Test/03869.png
#  extracting: Test/03870.png
#   inflating: Test/03871.png
#  extracting: Test/03872.png
#  extracting: Test/03873.png
#  extracting: Test/03874.png
#  extracting: Test/03875.png
#  extracting: Test/03876.png
#  extracting: Test/03877.png
#  extracting: Test/03878.png
#  extracting: Test/03879.png
#  extracting: Test/03880.png
#  extracting: Test/03881.png
#  extracting: Test/03882.png
#  extracting: Test/03883.png
#  extracting: Test/03884.png
#  extracting: Test/03885.png
#  extracting: Test/03886.png
#  extracting: Test/03887.png
#  extracting: Test/03888.png
#  extracting: Test/03889.png
#  extracting: Test/03890.png
#  extracting: Test/03891.png
#  extracting: Test/03892.png
#  extracting: Test/03893.png
#  extracting: Test/03894.png
#  extracting: Test/03895.png
#  extracting: Test/03896.png
#  extracting: Test/03897.png
#  extracting: Test/03898.png
#  extracting: Test/03899.png
#  extracting: Test/03900.png
#  extracting: Test/03901.png
#  extracting: Test/03902.png
#  extracting: Test/03903.png
#  extracting: Test/03904.png
#  extracting: Test/03905.png
#  extracting: Test/03906.png
#  extracting: Test/03907.png
#  extracting: Test/03908.png
#  extracting: Test/03909.png
#  extracting: Test/03910.png
#  extracting: Test/03911.png
#  extracting: Test/03912.png
#  extracting: Test/03913.png
#  extracting: Test/03914.png
#  extracting: Test/03915.png
#  extracting: Test/03916.png
#   inflating: Test/03917.png
#  extracting: Test/03918.png
#  extracting: Test/03919.png
#  extracting: Test/03920.png
#  extracting: Test/03921.png
#  extracting: Test/03922.png
#  extracting: Test/03923.png
#   inflating: Test/03924.png
#   inflating: Test/03925.png
#  extracting: Test/03926.png
#   inflating: Test/03927.png
#  extracting: Test/03928.png
#  extracting: Test/03929.png
#  extracting: Test/03930.png
#  extracting: Test/03931.png
#  extracting: Test/03932.png
#  extracting: Test/03933.png
#  extracting: Test/03934.png
#  extracting: Test/03935.png
#  extracting: Test/03936.png
#  extracting: Test/03937.png
#  extracting: Test/03938.png
#   inflating: Test/03939.png
#  extracting: Test/03940.png
#  extracting: Test/03941.png
#  extracting: Test/03942.png
#  extracting: Test/03943.png
#  extracting: Test/03944.png
#  extracting: Test/03945.png
#  extracting: Test/03946.png
#  extracting: Test/03947.png
#  extracting: Test/03948.png
#  extracting: Test/03949.png
#  extracting: Test/03950.png
#  extracting: Test/03951.png
#  extracting: Test/03952.png
#  extracting: Test/03953.png
#  extracting: Test/03954.png
#  extracting: Test/03955.png
#  extracting: Test/03956.png
#  extracting: Test/03957.png
#  extracting: Test/03958.png
#  extracting: Test/03959.png
#  extracting: Test/03960.png
#  extracting: Test/03961.png
#  extracting: Test/03962.png
#  extracting: Test/03963.png
#  extracting: Test/03964.png
#  extracting: Test/03965.png
#  extracting: Test/03966.png
#  extracting: Test/03967.png
#  extracting: Test/03968.png
#  extracting: Test/03969.png
#  extracting: Test/03970.png
#  extracting: Test/03971.png
#  extracting: Test/03972.png
#  extracting: Test/03973.png
#  extracting: Test/03974.png
#   inflating: Test/03975.png
#  extracting: Test/03976.png
#  extracting: Test/03977.png
#   inflating: Test/03978.png
#  extracting: Test/03979.png
#  extracting: Test/03980.png
#  extracting: Test/03981.png
#  extracting: Test/03982.png
#  extracting: Test/03983.png
#  extracting: Test/03984.png
#  extracting: Test/03985.png
#  extracting: Test/03986.png
#   inflating: Test/03987.png
#  extracting: Test/03988.png
#   inflating: Test/03989.png
#   inflating: Test/03990.png
#  extracting: Test/03991.png
#  extracting: Test/03992.png
#  extracting: Test/03993.png
#  extracting: Test/03994.png
#  extracting: Test/03995.png
#   inflating: Test/03996.png
#  extracting: Test/03997.png
#  extracting: Test/03998.png
#  extracting: Test/03999.png
#  extracting: Test/04000.png
#  extracting: Test/04001.png
#  extracting: Test/04002.png
#  extracting: Test/04003.png
#  extracting: Test/04004.png
#  extracting: Test/04005.png
#  extracting: Test/04006.png
#  extracting: Test/04007.png
#  extracting: Test/04008.png
#  extracting: Test/04009.png
#  extracting: Test/04010.png
#  extracting: Test/04011.png
#  extracting: Test/04012.png
#  extracting: Test/04013.png
#  extracting: Test/04014.png
#  extracting: Test/04015.png
#  extracting: Test/04016.png
#  extracting: Test/04017.png
#  extracting: Test/04018.png
#  extracting: Test/04019.png
#  extracting: Test/04020.png
#  extracting: Test/04021.png
#   inflating: Test/04022.png
#  extracting: Test/04023.png
#  extracting: Test/04024.png
#  extracting: Test/04025.png
#   inflating: Test/04026.png
#  extracting: Test/04027.png
#  extracting: Test/04028.png
#  extracting: Test/04029.png
#  extracting: Test/04030.png
#  extracting: Test/04031.png
#  extracting: Test/04032.png
#  extracting: Test/04033.png
#   inflating: Test/04034.png
#  extracting: Test/04035.png
#  extracting: Test/04036.png
#  extracting: Test/04037.png
#   inflating: Test/04038.png
#  extracting: Test/04039.png
#  extracting: Test/04040.png
#  extracting: Test/04041.png
#   inflating: Test/04042.png
#   inflating: Test/04043.png
#  extracting: Test/04044.png
#  extracting: Test/04045.png
#   inflating: Test/04046.png
#  extracting: Test/04047.png
#  extracting: Test/04048.png
#  extracting: Test/04049.png
#  extracting: Test/04050.png
#  extracting: Test/04051.png
#  extracting: Test/04052.png
#  extracting: Test/04053.png
#  extracting: Test/04054.png
#  extracting: Test/04055.png
#   inflating: Test/04056.png
#  extracting: Test/04057.png
#   inflating: Test/04058.png
#  extracting: Test/04059.png
#  extracting: Test/04060.png
#  extracting: Test/04061.png
#  extracting: Test/04062.png
#  extracting: Test/04063.png
#  extracting: Test/04064.png
#  extracting: Test/04065.png
#   inflating: Test/04066.png
#  extracting: Test/04067.png
#  extracting: Test/04068.png
#  extracting: Test/04069.png
#   inflating: Test/04070.png
#  extracting: Test/04071.png
#  extracting: Test/04072.png
#  extracting: Test/04073.png
#  extracting: Test/04074.png
#  extracting: Test/04075.png
#  extracting: Test/04076.png
#  extracting: Test/04077.png
#  extracting: Test/04078.png
#   inflating: Test/04079.png
#  extracting: Test/04080.png
#  extracting: Test/04081.png
#  extracting: Test/04082.png
#   inflating: Test/04083.png
#  extracting: Test/04084.png
#  extracting: Test/04085.png
#  extracting: Test/04086.png
#  extracting: Test/04087.png
#  extracting: Test/04088.png
#  extracting: Test/04089.png
#  extracting: Test/04090.png
#  extracting: Test/04091.png
#  extracting: Test/04092.png
#  extracting: Test/04093.png
#  extracting: Test/04094.png
#  extracting: Test/04095.png
#  extracting: Test/04096.png
#  extracting: Test/04097.png
#  extracting: Test/04098.png
#   inflating: Test/04099.png
#  extracting: Test/04100.png
#  extracting: Test/04101.png
#  extracting: Test/04102.png
#  extracting: Test/04103.png
#  extracting: Test/04104.png
#  extracting: Test/04105.png
#  extracting: Test/04106.png
#  extracting: Test/04107.png
#  extracting: Test/04108.png
#  extracting: Test/04109.png
#  extracting: Test/04110.png
#  extracting: Test/04111.png
#  extracting: Test/04112.png
#   inflating: Test/04113.png
#  extracting: Test/04114.png
#  extracting: Test/04115.png
#  extracting: Test/04116.png
#  extracting: Test/04117.png
#  extracting: Test/04118.png
#  extracting: Test/04119.png
#  extracting: Test/04120.png
#  extracting: Test/04121.png
#  extracting: Test/04122.png
#  extracting: Test/04123.png
#  extracting: Test/04124.png
#  extracting: Test/04125.png
#  extracting: Test/04126.png
#  extracting: Test/04127.png
#  extracting: Test/04128.png
#  extracting: Test/04129.png
#   inflating: Test/04130.png
#  extracting: Test/04131.png
#  extracting: Test/04132.png
#  extracting: Test/04133.png
#  extracting: Test/04134.png
#  extracting: Test/04135.png
#  extracting: Test/04136.png
#  extracting: Test/04137.png
#  extracting: Test/04138.png
#  extracting: Test/04139.png
#  extracting: Test/04140.png
#  extracting: Test/04141.png
#  extracting: Test/04142.png
#  extracting: Test/04143.png
#  extracting: Test/04144.png
#  extracting: Test/04145.png
#   inflating: Test/04146.png
#  extracting: Test/04147.png
#  extracting: Test/04148.png
#  extracting: Test/04149.png
#  extracting: Test/04150.png
#   inflating: Test/04151.png
#  extracting: Test/04152.png
#  extracting: Test/04153.png
#  extracting: Test/04154.png
#  extracting: Test/04155.png
#  extracting: Test/04156.png
#  extracting: Test/04157.png
#  extracting: Test/04158.png
#   inflating: Test/04159.png
#  extracting: Test/04160.png
#  extracting: Test/04161.png
#  extracting: Test/04162.png
#  extracting: Test/04163.png
#   inflating: Test/04164.png
#   inflating: Test/04165.png
#  extracting: Test/04166.png
#  extracting: Test/04167.png
#  extracting: Test/04168.png
#  extracting: Test/04169.png
#  extracting: Test/04170.png
#  extracting: Test/04171.png
#  extracting: Test/04172.png
#  extracting: Test/04173.png
#  extracting: Test/04174.png
#  extracting: Test/04175.png
#  extracting: Test/04176.png
#  extracting: Test/04177.png
#  extracting: Test/04178.png
#  extracting: Test/04179.png
#  extracting: Test/04180.png
#  extracting: Test/04181.png
#  extracting: Test/04182.png
#  extracting: Test/04183.png
#  extracting: Test/04184.png
#  extracting: Test/04185.png
#  extracting: Test/04186.png
#  extracting: Test/04187.png
#  extracting: Test/04188.png
#  extracting: Test/04189.png
#   inflating: Test/04190.png
#  extracting: Test/04191.png
#  extracting: Test/04192.png
#   inflating: Test/04193.png
#   inflating: Test/04194.png
#   inflating: Test/04195.png
#  extracting: Test/04196.png
#  extracting: Test/04197.png
#  extracting: Test/04198.png
#  extracting: Test/04199.png
#   inflating: Test/04200.png
#  extracting: Test/04201.png
#  extracting: Test/04202.png
#  extracting: Test/04203.png
#  extracting: Test/04204.png
#  extracting: Test/04205.png
#  extracting: Test/04206.png
#  extracting: Test/04207.png
#  extracting: Test/04208.png
#  extracting: Test/04209.png
#  extracting: Test/04210.png
#  extracting: Test/04211.png
#  extracting: Test/04212.png
#   inflating: Test/04213.png
#  extracting: Test/04214.png
#  extracting: Test/04215.png
#  extracting: Test/04216.png
#  extracting: Test/04217.png
#  extracting: Test/04218.png
#  extracting: Test/04219.png
#  extracting: Test/04220.png
#  extracting: Test/04221.png
#  extracting: Test/04222.png
#  extracting: Test/04223.png
#  extracting: Test/04224.png
#  extracting: Test/04225.png
#  extracting: Test/04226.png
#  extracting: Test/04227.png
#   inflating: Test/04228.png
#  extracting: Test/04229.png
#  extracting: Test/04230.png
#  extracting: Test/04231.png
#  extracting: Test/04232.png
#  extracting: Test/04233.png
#  extracting: Test/04234.png
#  extracting: Test/04235.png
#  extracting: Test/04236.png
#  extracting: Test/04237.png
#  extracting: Test/04238.png
#  extracting: Test/04239.png
#  extracting: Test/04240.png
#  extracting: Test/04241.png
#  extracting: Test/04242.png
#  extracting: Test/04243.png
#  extracting: Test/04244.png
#  extracting: Test/04245.png
#   inflating: Test/04246.png
#  extracting: Test/04247.png
#  extracting: Test/04248.png
#  extracting: Test/04249.png
#   inflating: Test/04250.png
#  extracting: Test/04251.png
#  extracting: Test/04252.png
#  extracting: Test/04253.png
#   inflating: Test/04254.png
#  extracting: Test/04255.png
#  extracting: Test/04256.png
#  extracting: Test/04257.png
#  extracting: Test/04258.png
#   inflating: Test/04259.png
#  extracting: Test/04260.png
#  extracting: Test/04261.png
#  extracting: Test/04262.png
#  extracting: Test/04263.png
#  extracting: Test/04264.png
#  extracting: Test/04265.png
#  extracting: Test/04266.png
#  extracting: Test/04267.png
#  extracting: Test/04268.png
#  extracting: Test/04269.png
#  extracting: Test/04270.png
#  extracting: Test/04271.png
#  extracting: Test/04272.png
#  extracting: Test/04273.png
#  extracting: Test/04274.png
#  extracting: Test/04275.png
#  extracting: Test/04276.png
#  extracting: Test/04277.png
#  extracting: Test/04278.png
#  extracting: Test/04279.png
#  extracting: Test/04280.png
#  extracting: Test/04281.png
#  extracting: Test/04282.png
#  extracting: Test/04283.png
#  extracting: Test/04284.png
#  extracting: Test/04285.png
#   inflating: Test/04286.png
#  extracting: Test/04287.png
#   inflating: Test/04288.png
#  extracting: Test/04289.png
#  extracting: Test/04290.png
#  extracting: Test/04291.png
#  extracting: Test/04292.png
#  extracting: Test/04293.png
#  extracting: Test/04294.png
#  extracting: Test/04295.png
#   inflating: Test/04296.png
#  extracting: Test/04297.png
#  extracting: Test/04298.png
#  extracting: Test/04299.png
#  extracting: Test/04300.png
#  extracting: Test/04301.png
#  extracting: Test/04302.png
#  extracting: Test/04303.png
#  extracting: Test/04304.png
#  extracting: Test/04305.png
#  extracting: Test/04306.png
#  extracting: Test/04307.png
#   inflating: Test/04308.png
#  extracting: Test/04309.png
#   inflating: Test/04310.png
#  extracting: Test/04311.png
#  extracting: Test/04312.png
#  extracting: Test/04313.png
#   inflating: Test/04314.png
#  extracting: Test/04315.png
#  extracting: Test/04316.png
#  extracting: Test/04317.png
#   inflating: Test/04318.png
#  extracting: Test/04319.png
#  extracting: Test/04320.png
#  extracting: Test/04321.png
#  extracting: Test/04322.png
#  extracting: Test/04323.png
#  extracting: Test/04324.png
#  extracting: Test/04325.png
#  extracting: Test/04326.png
#  extracting: Test/04327.png
#  extracting: Test/04328.png
#  extracting: Test/04329.png
#   inflating: Test/04330.png
#  extracting: Test/04331.png
#  extracting: Test/04332.png
#  extracting: Test/04333.png
#  extracting: Test/04334.png
#  extracting: Test/04335.png
#  extracting: Test/04336.png
#  extracting: Test/04337.png
#  extracting: Test/04338.png
#  extracting: Test/04339.png
#  extracting: Test/04340.png
#  extracting: Test/04341.png
#  extracting: Test/04342.png
#  extracting: Test/04343.png
#  extracting: Test/04344.png
#  extracting: Test/04345.png
#  extracting: Test/04346.png
#  extracting: Test/04347.png
#  extracting: Test/04348.png
#  extracting: Test/04349.png
#   inflating: Test/04350.png
#  extracting: Test/04351.png
#  extracting: Test/04352.png
#  extracting: Test/04353.png
#  extracting: Test/04354.png
#  extracting: Test/04355.png
#  extracting: Test/04356.png
#  extracting: Test/04357.png
#  extracting: Test/04358.png
#  extracting: Test/04359.png
#   inflating: Test/04360.png
#  extracting: Test/04361.png
#  extracting: Test/04362.png
#  extracting: Test/04363.png
#  extracting: Test/04364.png
#  extracting: Test/04365.png
#  extracting: Test/04366.png
#  extracting: Test/04367.png
#   inflating: Test/04368.png
#  extracting: Test/04369.png
#  extracting: Test/04370.png
#  extracting: Test/04371.png
#   inflating: Test/04372.png
#  extracting: Test/04373.png
#  extracting: Test/04374.png
#  extracting: Test/04375.png
#  extracting: Test/04376.png
#  extracting: Test/04377.png
#  extracting: Test/04378.png
#  extracting: Test/04379.png
#  extracting: Test/04380.png
#  extracting: Test/04381.png
#  extracting: Test/04382.png
#  extracting: Test/04383.png
#  extracting: Test/04384.png
#  extracting: Test/04385.png
#  extracting: Test/04386.png
#  extracting: Test/04387.png
#  extracting: Test/04388.png
#  extracting: Test/04389.png
#  extracting: Test/04390.png
#  extracting: Test/04391.png
#  extracting: Test/04392.png
#   inflating: Test/04393.png
#  extracting: Test/04394.png
#   inflating: Test/04395.png
#  extracting: Test/04396.png
#  extracting: Test/04397.png
#  extracting: Test/04398.png
#  extracting: Test/04399.png
#  extracting: Test/04400.png
#   inflating: Test/04401.png
#  extracting: Test/04402.png
#  extracting: Test/04403.png
#  extracting: Test/04404.png
#  extracting: Test/04405.png
#  extracting: Test/04406.png
#  extracting: Test/04407.png
#  extracting: Test/04408.png
#  extracting: Test/04409.png
#  extracting: Test/04410.png
#  extracting: Test/04411.png
#  extracting: Test/04412.png
#   inflating: Test/04413.png
#  extracting: Test/04414.png
#  extracting: Test/04415.png
#  extracting: Test/04416.png
#  extracting: Test/04417.png
#  extracting: Test/04418.png
#  extracting: Test/04419.png
#   inflating: Test/04420.png
#   inflating: Test/04421.png
#  extracting: Test/04422.png
#  extracting: Test/04423.png
#  extracting: Test/04424.png
#   inflating: Test/04425.png
#  extracting: Test/04426.png
#   inflating: Test/04427.png
#  extracting: Test/04428.png
#  extracting: Test/04429.png
#   inflating: Test/04430.png
#   inflating: Test/04431.png
#  extracting: Test/04432.png
#  extracting: Test/04433.png
#  extracting: Test/04434.png
#  extracting: Test/04435.png
#  extracting: Test/04436.png
#   inflating: Test/04437.png
#   inflating: Test/04438.png
#  extracting: Test/04439.png
#   inflating: Test/04440.png
#  extracting: Test/04441.png
#  extracting: Test/04442.png
#  extracting: Test/04443.png
#  extracting: Test/04444.png
#  extracting: Test/04445.png
#  extracting: Test/04446.png
#  extracting: Test/04447.png
#  extracting: Test/04448.png
#  extracting: Test/04449.png
#  extracting: Test/04450.png
#  extracting: Test/04451.png
#   inflating: Test/04452.png
#  extracting: Test/04453.png
#   inflating: Test/04454.png
#  extracting: Test/04455.png
#  extracting: Test/04456.png
#  extracting: Test/04457.png
#  extracting: Test/04458.png
#   inflating: Test/04459.png
#  extracting: Test/04460.png
#  extracting: Test/04461.png
#  extracting: Test/04462.png
#  extracting: Test/04463.png
#  extracting: Test/04464.png
#  extracting: Test/04465.png
#  extracting: Test/04466.png
#  extracting: Test/04467.png
#  extracting: Test/04468.png
#   inflating: Test/04469.png
#  extracting: Test/04470.png
#  extracting: Test/04471.png
#  extracting: Test/04472.png
#  extracting: Test/04473.png
#  extracting: Test/04474.png
#  extracting: Test/04475.png
#  extracting: Test/04476.png
#  extracting: Test/04477.png
#  extracting: Test/04478.png
#  extracting: Test/04479.png
#  extracting: Test/04480.png
#   inflating: Test/04481.png
#  extracting: Test/04482.png
#  extracting: Test/04483.png
#  extracting: Test/04484.png
#  extracting: Test/04485.png
#  extracting: Test/04486.png
#  extracting: Test/04487.png
#   inflating: Test/04488.png
#  extracting: Test/04489.png
#   inflating: Test/04490.png
#  extracting: Test/04491.png
#  extracting: Test/04492.png
#   inflating: Test/04493.png
#  extracting: Test/04494.png
#  extracting: Test/04495.png
#  extracting: Test/04496.png
#  extracting: Test/04497.png
#  extracting: Test/04498.png
#  extracting: Test/04499.png
#  extracting: Test/04500.png
#  extracting: Test/04501.png
#   inflating: Test/04502.png
#  extracting: Test/04503.png
#  extracting: Test/04504.png
#  extracting: Test/04505.png
#   inflating: Test/04506.png
#  extracting: Test/04507.png
#  extracting: Test/04508.png
#  extracting: Test/04509.png
#  extracting: Test/04510.png
#  extracting: Test/04511.png
#  extracting: Test/04512.png
#  extracting: Test/04513.png
#  extracting: Test/04514.png
#  extracting: Test/04515.png
#   inflating: Test/04516.png
#  extracting: Test/04517.png
#  extracting: Test/04518.png
#  extracting: Test/04519.png
#   inflating: Test/04520.png
#  extracting: Test/04521.png
#  extracting: Test/04522.png
#  extracting: Test/04523.png
#  extracting: Test/04524.png
#  extracting: Test/04525.png
#  extracting: Test/04526.png
#  extracting: Test/04527.png
#  extracting: Test/04528.png
#   inflating: Test/04529.png
#  extracting: Test/04530.png
#  extracting: Test/04531.png
#  extracting: Test/04532.png
#   inflating: Test/04533.png
#  extracting: Test/04534.png
#  extracting: Test/04535.png
#  extracting: Test/04536.png
#  extracting: Test/04537.png
#  extracting: Test/04538.png
#  extracting: Test/04539.png
#  extracting: Test/04540.png
#  extracting: Test/04541.png
#  extracting: Test/04542.png
#  extracting: Test/04543.png
#  extracting: Test/04544.png
#  extracting: Test/04545.png
#  extracting: Test/04546.png
#  extracting: Test/04547.png
#   inflating: Test/04548.png
#  extracting: Test/04549.png
#  extracting: Test/04550.png
#  extracting: Test/04551.png
#  extracting: Test/04552.png
#   inflating: Test/04553.png
#  extracting: Test/04554.png
#  extracting: Test/04555.png
#  extracting: Test/04556.png
#  extracting: Test/04557.png
#  extracting: Test/04558.png
#   inflating: Test/04559.png
#  extracting: Test/04560.png
#  extracting: Test/04561.png
#  extracting: Test/04562.png
#  extracting: Test/04563.png
#  extracting: Test/04564.png
#  extracting: Test/04565.png
#  extracting: Test/04566.png
#  extracting: Test/04567.png
#  extracting: Test/04568.png
#   inflating: Test/04569.png
#  extracting: Test/04570.png
#   inflating: Test/04571.png
#  extracting: Test/04572.png
#  extracting: Test/04573.png
#  extracting: Test/04574.png
#  extracting: Test/04575.png
#  extracting: Test/04576.png
#  extracting: Test/04577.png
#   inflating: Test/04578.png
#  extracting: Test/04579.png
#  extracting: Test/04580.png
#  extracting: Test/04581.png
#   inflating: Test/04582.png
#  extracting: Test/04583.png
#   inflating: Test/04584.png
#   inflating: Test/04585.png
#  extracting: Test/04586.png
#  extracting: Test/04587.png
#  extracting: Test/04588.png
#  extracting: Test/04589.png
#  extracting: Test/04590.png
#  extracting: Test/04591.png
#  extracting: Test/04592.png
#  extracting: Test/04593.png
#  extracting: Test/04594.png
#  extracting: Test/04595.png
#   inflating: Test/04596.png
#  extracting: Test/04597.png
#   inflating: Test/04598.png
#  extracting: Test/04599.png
#  extracting: Test/04600.png
#  extracting: Test/04601.png
#  extracting: Test/04602.png
#  extracting: Test/04603.png
#  extracting: Test/04604.png
#  extracting: Test/04605.png
#   inflating: Test/04606.png
#  extracting: Test/04607.png
#   inflating: Test/04608.png
#  extracting: Test/04609.png
#  extracting: Test/04610.png
#   inflating: Test/04611.png
#  extracting: Test/04612.png
#  extracting: Test/04613.png
#  extracting: Test/04614.png
#  extracting: Test/04615.png
#  extracting: Test/04616.png
#  extracting: Test/04617.png
#  extracting: Test/04618.png
#  extracting: Test/04619.png
#   inflating: Test/04620.png
#  extracting: Test/04621.png
#   inflating: Test/04622.png
#  extracting: Test/04623.png
#  extracting: Test/04624.png
#  extracting: Test/04625.png
#  extracting: Test/04626.png
#  extracting: Test/04627.png
#  extracting: Test/04628.png
#  extracting: Test/04629.png
#  extracting: Test/04630.png
#   inflating: Test/04631.png
#  extracting: Test/04632.png
#  extracting: Test/04633.png
#   inflating: Test/04634.png
#  extracting: Test/04635.png
#  extracting: Test/04636.png
#  extracting: Test/04637.png
#  extracting: Test/04638.png
#  extracting: Test/04640.png
#  extracting: Test/04641.png
#   inflating: Test/04643.png
#  extracting: Test/04644.png
#  extracting: Test/04645.png
#  extracting: Test/04646.png
#  extracting: Test/04647.png
#  extracting: Test/04648.png
#  extracting: Test/04649.png
#  extracting: Test/04650.png
#  extracting: Test/04651.png
#  extracting: Test/04652.png
#  extracting: Test/04653.png
#  extracting: Test/04654.png
#  extracting: Test/04655.png
#  extracting: Test/04656.png
#  extracting: Test/04657.png
#  extracting: Test/04658.png
#  extracting: Test/04659.png
#   inflating: Test/04660.png
#  extracting: Test/04661.png
#   inflating: Test/04662.png
#  extracting: Test/04663.png
#   inflating: Test/04664.png
#  extracting: Test/04665.png
#   inflating: Test/04666.png
#  extracting: Test/04667.png
#  extracting: Test/04668.png
#   inflating: Test/04669.png
#  extracting: Test/04670.png
#  extracting: Test/04671.png
#  extracting: Test/04672.png
#  extracting: Test/04673.png
#  extracting: Test/04674.png
#  extracting: Test/04675.png
#  extracting: Test/04676.png
#  extracting: Test/04677.png
#  extracting: Test/04678.png
#  extracting: Test/04679.png
#   inflating: Test/04680.png
#  extracting: Test/04681.png
#   inflating: Test/04682.png
#   inflating: Test/04683.png
#  extracting: Test/04684.png
#  extracting: Test/04685.png
#  extracting: Test/04686.png
#  extracting: Test/04687.png
#  extracting: Test/04688.png
#  extracting: Test/04689.png
#  extracting: Test/04690.png
#  extracting: Test/04691.png
#   inflating: Test/04692.png
#  extracting: Test/04693.png
#  extracting: Test/04694.png
#  extracting: Test/04695.png
#  extracting: Test/04696.png
#  extracting: Test/04697.png
#   inflating: Test/04698.png
#  extracting: Test/04699.png
#  extracting: Test/04700.png
#  extracting: Test/04701.png
#  extracting: Test/04702.png
#  extracting: Test/04703.png
#   inflating: Test/04704.png
#  extracting: Test/04705.png
#  extracting: Test/04706.png
#  extracting: Test/04707.png
#  extracting: Test/04708.png
#  extracting: Test/04709.png
#   inflating: Test/04710.png
#  extracting: Test/04711.png
#  extracting: Test/04712.png
#  extracting: Test/04713.png
#  extracting: Test/04714.png
#  extracting: Test/04715.png
#   inflating: Test/04716.png
#  extracting: Test/04717.png
#   inflating: Test/04718.png
#  extracting: Test/04719.png
#  extracting: Test/04720.png
#  extracting: Test/04721.png
#  extracting: Test/04722.png
#  extracting: Test/04723.png
#   inflating: Test/04724.png
#  extracting: Test/04725.png
#  extracting: Test/04726.png
#  extracting: Test/04727.png
#  extracting: Test/04728.png
#  extracting: Test/04729.png
#  extracting: Test/04730.png
#  extracting: Test/04731.png
#   inflating: Test/04732.png
#  extracting: Test/04733.png
#  extracting: Test/04734.png
#  extracting: Test/04735.png
#  extracting: Test/04736.png
#  extracting: Test/04737.png
#  extracting: Test/04738.png
#   inflating: Test/04739.png
#  extracting: Test/04740.png
#   inflating: Test/04741.png
#  extracting: Test/04742.png
#  extracting: Test/04743.png
#  extracting: Test/04744.png
#  extracting: Test/04745.png
#  extracting: Test/04746.png
#  extracting: Test/04747.png
#  extracting: Test/04748.png
#  extracting: Test/04749.png
#  extracting: Test/04750.png
#  extracting: Test/04751.png
#   inflating: Test/04752.png
#  extracting: Test/04753.png
#  extracting: Test/04754.png
#  extracting: Test/04755.png
#  extracting: Test/04756.png
#  extracting: Test/04757.png
#  extracting: Test/04758.png
#  extracting: Test/04759.png
#  extracting: Test/04760.png
#  extracting: Test/04761.png
#  extracting: Test/04762.png
#  extracting: Test/04763.png
#  extracting: Test/04764.png
#  extracting: Test/04766.png
#  extracting: Test/04767.png
#  extracting: Test/04768.png
#  extracting: Test/04769.png
#  extracting: Test/04770.png
#  extracting: Test/04771.png
#   inflating: Test/04773.png
#   inflating: Test/04774.png
#  extracting: Test/04775.png
#   inflating: Test/04776.png
#   inflating: Test/04777.png
#  extracting: Test/04778.png
#  extracting: Test/04779.png
#   inflating: Test/04780.png
#  extracting: Test/04781.png
#  extracting: Test/04782.png
#  extracting: Test/04783.png
#  extracting: Test/04784.png
#  extracting: Test/04785.png
#   inflating: Test/04786.png
#  extracting: Test/04787.png
#   inflating: Test/04788.png
#  extracting: Test/04789.png
#  extracting: Test/04790.png
#  extracting: Test/04791.png
#  extracting: Test/04792.png
#  extracting: Test/04793.png
#  extracting: Test/04794.png
#  extracting: Test/04795.png
#  extracting: Test/04796.png
#  extracting: Test/04797.png
#  extracting: Test/04798.png
#  extracting: Test/04799.png
#   inflating: Test/04800.png
#  extracting: Test/04801.png
#  extracting: Test/04802.png
#  extracting: Test/04803.png
#  extracting: Test/04804.png
#   inflating: Test/04805.png
#  extracting: Test/04806.png
#  extracting: Test/04807.png
#   inflating: Test/04808.png
#  extracting: Test/04809.png
#  extracting: Test/04810.png
#  extracting: Test/04811.png
#  extracting: Test/04812.png
#  extracting: Test/04813.png
#  extracting: Test/04814.png
#  extracting: Test/04815.png
#  extracting: Test/04816.png
#  extracting: Test/04817.png
#  extracting: Test/04818.png
#  extracting: Test/04819.png
#  extracting: Test/04820.png
#  extracting: Test/04821.png
#  extracting: Test/04822.png
#  extracting: Test/04823.png
#   inflating: Test/04824.png
#  extracting: Test/04825.png
#  extracting: Test/04826.png
#  extracting: Test/04827.png
#  extracting: Test/04828.png
#  extracting: Test/04829.png
#  extracting: Test/04830.png
#  extracting: Test/04831.png
#  extracting: Test/04832.png
#  extracting: Test/04834.png
#  extracting: Test/04835.png
#  extracting: Test/04836.png
#  extracting: Test/04837.png
#  extracting: Test/04838.png
#  extracting: Test/04839.png
#  extracting: Test/04840.png
#  extracting: Test/04841.png
#  extracting: Test/04842.png
#  extracting: Test/04843.png
#  extracting: Test/04844.png
#  extracting: Test/04845.png
#  extracting: Test/04846.png
#   inflating: Test/04847.png
#  extracting: Test/04848.png
#  extracting: Test/04849.png
#  extracting: Test/04850.png
#  extracting: Test/04851.png
#  extracting: Test/04852.png
#  extracting: Test/04853.png
#  extracting: Test/04854.png
#  extracting: Test/04855.png
#  extracting: Test/04856.png
#  extracting: Test/04857.png
#  extracting: Test/04858.png
#  extracting: Test/04859.png
#  extracting: Test/04860.png
#  extracting: Test/04861.png
#  extracting: Test/04862.png
#   inflating: Test/04863.png
#  extracting: Test/04864.png
#  extracting: Test/04865.png
#  extracting: Test/04866.png
#  extracting: Test/04867.png
#   inflating: Test/04868.png
#  extracting: Test/04869.png
#  extracting: Test/04870.png
#  extracting: Test/04871.png
#  extracting: Test/04872.png
#  extracting: Test/04873.png
#  extracting: Test/04874.png
#  extracting: Test/04875.png
#  extracting: Test/04876.png
#  extracting: Test/04877.png
#  extracting: Test/04878.png
#  extracting: Test/04879.png
#  extracting: Test/04880.png
#  extracting: Test/04881.png
#  extracting: Test/04882.png
#  extracting: Test/04883.png
#  extracting: Test/04884.png
#  extracting: Test/04885.png
#  extracting: Test/04886.png
#  extracting: Test/04887.png
#  extracting: Test/04888.png
#  extracting: Test/04889.png
#  extracting: Test/04890.png
#  extracting: Test/04891.png
#  extracting: Test/04892.png
#  extracting: Test/04893.png
#  extracting: Test/04894.png
#  extracting: Test/04895.png
#  extracting: Test/04896.png
#   inflating: Test/04897.png
#  extracting: Test/04898.png
#   inflating: Test/04899.png
#  extracting: Test/04900.png
#   inflating: Test/04901.png
#  extracting: Test/04902.png
#  extracting: Test/04903.png
#  extracting: Test/04904.png
#  extracting: Test/04905.png
#  extracting: Test/04906.png
#  extracting: Test/04907.png
#  extracting: Test/04909.png
#  extracting: Test/04910.png
#  extracting: Test/04911.png
#  extracting: Test/04912.png
#   inflating: Test/04913.png
#  extracting: Test/04914.png
#  extracting: Test/04915.png
#  extracting: Test/04916.png
#  extracting: Test/04917.png
#  extracting: Test/04918.png
#  extracting: Test/04919.png
#  extracting: Test/04920.png
#  extracting: Test/04921.png
#  extracting: Test/04922.png
#  extracting: Test/04923.png
#   inflating: Test/04924.png
#  extracting: Test/04925.png
#  extracting: Test/04926.png
#  extracting: Test/04927.png
#  extracting: Test/04928.png
#  extracting: Test/04929.png
#  extracting: Test/04930.png
#  extracting: Test/04931.png
#  extracting: Test/04932.png
#  extracting: Test/04933.png
#  extracting: Test/04934.png
#  extracting: Test/04935.png
#  extracting: Test/04936.png
#  extracting: Test/04937.png
# ...
#  extracting: Test/10497.png
#  extracting: Test/10498.png
#  extracting: Test/10504.png
#  extracting: Test/10505.png
#  extracting: Test/10508.png
#  extracting: Test/10514.png
#  extracting: Test/10516.png
#  extracting: Test/10517.png
#  extracting: Test/10518.png
#  extracting: Test/10523.png
#  extracting: Test/10524.png
#  extracting: Test/10525.png
#  extracting: Test/10531.png
#  extracting: Test/10533.png
#  extracting: Test/10535.png
#  extracting: Test/10536.png
#  extracting: Test/10538.png
#   inflating: Test/10541.png
#  extracting: Test/10550.png
#  extracting: Test/10553.png
#  extracting: Test/10555.png
#  extracting: Test/10557.png
#  extracting: Test/10566.png
#   inflating: Test/10567.png
#  extracting: Test/10568.png
#  extracting: Test/10570.png
#  extracting: Test/10579.png
#  extracting: Test/10587.png
#  extracting: Test/10592.png
#  extracting: Test/10595.png
#  extracting: Test/10596.png
#  extracting: Test/10604.png
#  extracting: Test/10605.png
#  extracting: Test/10607.png
#  extracting: Test/10608.png
#  extracting: Test/10610.png
#   inflating: Test/10616.png
#  extracting: Test/10618.png
#  extracting: Test/10620.png
#  extracting: Test/10625.png
#  extracting: Test/10626.png
#   inflating: Test/10627.png
#  extracting: Test/10628.png
#  extracting: Test/10629.png
#  extracting: Test/10634.png
#  extracting: Test/10639.png
#  extracting: Test/10647.png
#  extracting: Test/10655.png
#  extracting: Test/10658.png
#  extracting: Test/10667.png
#  extracting: Test/10669.png
#  extracting: Test/10675.png
#  extracting: Test/10680.png
#  extracting: Test/10681.png
#  extracting: Test/10682.png
#  extracting: Test/10685.png
#  extracting: Test/10686.png
#  extracting: Test/10693.png
#  extracting: Test/10698.png
#  extracting: Test/10699.png
#   inflating: Test/10701.png
#  extracting: Test/10703.png
#  extracting: Test/10716.png
#  extracting: Test/10726.png
#  extracting: Test/10731.png
#  extracting: Test/10736.png
#   inflating: Test/10739.png
#  extracting: Test/10740.png
#  extracting: Test/10744.png
#  extracting: Test/10745.png
#  extracting: Test/10747.png
#  extracting: Test/10755.png
#  extracting: Test/10759.png
#  extracting: Test/10763.png
#  extracting: Test/10773.png
#  extracting: Test/10783.png
#  extracting: Test/10785.png
#  extracting: Test/10788.png
#  extracting: Test/10791.png
#  extracting: Test/10792.png
#  extracting: Test/10793.png
#  extracting: Test/10795.png
#  extracting: Test/10798.png
#  extracting: Test/10799.png
#  extracting: Test/10801.png
#  extracting: Test/10804.png
#  extracting: Test/10806.png
#  extracting: Test/10807.png
#   inflating: Test/10818.png
#  extracting: Test/10819.png
#  extracting: Test/10820.png
#  extracting: Test/10824.png
#  extracting: Test/10826.png
#  extracting: Test/10831.png
#  extracting: Test/10836.png
#  extracting: Test/10838.png
#  extracting: Test/10840.png
#  extracting: Test/10842.png
#  extracting: Test/10852.png
#  extracting: Test/10854.png
#  extracting: Test/10856.png
#  extracting: Test/10857.png
#  extracting: Test/10861.png
#   inflating: Test/10863.png
#  extracting: Test/10864.png
#  extracting: Test/10865.png
#  extracting: Test/10866.png
#  extracting: Test/10867.png
#  extracting: Test/10873.png
#  extracting: Test/10876.png
#   inflating: Test/10878.png
#  extracting: Test/10881.png
#  extracting: Test/10889.png
#  extracting: Test/10891.png
#  extracting: Test/10892.png
#  extracting: Test/10893.png
#  extracting: Test/10896.png
#  extracting: Test/10897.png
#  extracting: Test/10902.png
#  extracting: Test/10904.png
#  extracting: Test/10910.png
#  extracting: Test/10913.png
#  extracting: Test/10914.png
#  extracting: Test/10915.png
#  extracting: Test/10925.png
#  extracting: Test/10929.png
#  extracting: Test/10933.png
#  extracting: Test/10937.png
#  extracting: Test/10943.png
#  extracting: Test/10944.png
#  extracting: Test/10945.png
#   inflating: Test/10948.png
#   inflating: Test/10949.png
#  extracting: Test/10958.png
#  extracting: Test/10965.png
#  extracting: Test/10966.png
#  extracting: Test/10980.png
#  extracting: Test/10984.png
#  extracting: Test/10988.png
#   inflating: Test/10990.png
#  extracting: Test/10991.png
#  extracting: Test/10994.png
#  extracting: Test/11000.png
#  extracting: Test/11001.png
#   inflating: Test/11002.png
#  extracting: Test/11003.png
#  extracting: Test/11007.png
#  extracting: Test/11014.png
#  extracting: Test/11015.png
#  extracting: Test/11016.png
#  extracting: Test/11017.png
#   inflating: Test/11019.png
#  extracting: Test/11020.png
#  extracting: Test/11022.png
#   inflating: Test/11023.png
#  extracting: Test/11027.png
#  extracting: Test/11029.png
#  extracting: Test/11030.png
#  extracting: Test/11031.png
#  extracting: Test/11034.png
#  extracting: Test/11036.png
#  extracting: Test/11037.png
#  extracting: Test/11039.png
#   inflating: Test/11042.png
#  extracting: Test/11045.png
#  extracting: Test/11046.png
#  extracting: Test/11050.png
#  extracting: Test/11051.png
#  extracting: Test/11058.png
#  extracting: Test/11059.png
#  extracting: Test/11062.png
#  extracting: Test/11066.png
#  extracting: Test/11071.png
#  extracting: Test/11075.png
#  extracting: Test/11078.png
#  extracting: Test/11082.png
#  extracting: Test/11085.png
#  extracting: Test/11086.png
#  extracting: Test/11088.png
#  extracting: Test/11101.png
#  extracting: Test/11111.png
#  extracting: Test/11112.png
#  extracting: Test/11115.png
#  extracting: Test/11122.png
#  extracting: Test/11129.png
#  extracting: Test/11135.png
#  extracting: Test/11138.png
#  extracting: Test/11144.png
#  extracting: Test/11145.png
#  extracting: Test/11146.png
#  extracting: Test/11150.png
#  extracting: Test/11155.png
#  extracting: Test/11162.png
#   inflating: Test/11163.png
#  extracting: Test/11168.png
#   inflating: Test/11169.png
#   inflating: Test/11180.png
#   inflating: Test/11181.png
#  extracting: Test/11182.png
#  extracting: Test/11184.png
#   inflating: Test/11186.png
#  extracting: Test/11188.png
#  extracting: Test/11199.png
#  extracting: Test/11201.png
#  extracting: Test/11202.png
#  extracting: Test/11203.png
#   inflating: Test/11204.png
#   inflating: Test/11205.png
#  extracting: Test/11207.png
#  extracting: Test/11210.png
#  extracting: Test/11213.png
#  extracting: Test/11218.png
#  extracting: Test/11222.png
#  extracting: Test/11227.png
#  extracting: Test/11230.png
#  extracting: Test/11232.png
#   inflating: Test/11238.png
#  extracting: Test/11243.png
#  extracting: Test/11249.png
#  extracting: Test/11250.png
#  extracting: Test/11255.png
#  extracting: Test/11258.png
#   inflating: Test/11260.png
#  extracting: Test/11261.png
#   inflating: Test/11268.png
#  extracting: Test/11269.png
#  extracting: Test/11270.png
#   inflating: Test/11276.png
#  extracting: Test/11285.png
#  extracting: Test/11290.png
#  extracting: Test/11302.png
#  extracting: Test/11303.png
#  extracting: Test/11308.png
#  extracting: Test/11309.png
#  extracting: Test/11310.png
#  extracting: Test/11312.png
#  extracting: Test/11321.png
#   inflating: Test/11329.png
#  extracting: Test/11332.png
#   inflating: Test/11343.png
#  extracting: Test/11346.png
#  extracting: Test/11354.png
#  extracting: Test/11361.png
#  extracting: Test/11364.png
#   inflating: Test/11366.png
#  extracting: Test/11383.png
#   inflating: Test/11396.png
#  extracting: Test/11397.png
#  extracting: Test/11399.png
#  extracting: Test/11414.png
#   inflating: Test/11415.png
#  extracting: Test/11417.png
#   inflating: Test/11418.png
#  extracting: Test/11423.png
#  extracting: Test/11442.png
#  extracting: Test/11444.png
#  extracting: Test/11447.png
#  extracting: Test/11449.png
#  extracting: Test/11450.png
#  extracting: Test/11453.png
#  extracting: Test/11460.png
#   inflating: Test/11465.png
#  extracting: Test/11471.png
#  extracting: Test/11481.png
#  extracting: Test/11485.png
#  extracting: Test/11486.png
#  extracting: Test/11487.png
#  extracting: Test/11489.png
#  extracting: Test/11497.png
#  extracting: Test/11498.png
#   inflating: Test/11508.png
#  extracting: Test/11516.png
#  extracting: Test/11518.png
#  extracting: Test/11524.png
#  extracting: Test/11527.png
#  extracting: Test/11532.png
#  extracting: Test/11534.png
#  extracting: Test/11544.png
#  extracting: Test/11547.png
#   inflating: Test/11549.png
#  extracting: Test/11556.png
#  extracting: Test/11559.png
#  extracting: Test/11570.png
#  extracting: Test/11571.png
#  extracting: Test/11572.png
#  extracting: Test/11600.png
#  extracting: Test/11606.png
#  extracting: Test/11608.png
#  extracting: Test/11610.png
#  extracting: Test/11618.png
#  extracting: Test/11619.png
#  extracting: Test/11629.png
#  extracting: Test/11630.png
#  extracting: Test/11631.png
#  extracting: Test/11637.png
#  extracting: Test/11639.png
#  extracting: Test/11641.png
#  extracting: Test/11648.png
#  extracting: Test/11649.png
#  extracting: Test/11650.png
#  extracting: Test/11654.png
#  extracting: Test/11662.png
#  extracting: Test/11663.png
#   inflating: Test/11670.png
#  extracting: Test/11675.png
#   inflating: Test/11676.png
#  extracting: Test/11682.png
#  extracting: Test/11684.png
#  extracting: Test/11691.png
#  extracting: Test/11692.png
#   inflating: Test/11705.png
#  extracting: Test/11708.png
#  extracting: Test/11710.png
#  extracting: Test/11713.png
#  extracting: Test/11718.png
#  extracting: Test/11724.png
#   inflating: Test/11727.png
#   inflating: Test/11731.png
#  extracting: Test/11735.png
#   inflating: Test/11740.png
#  extracting: Test/11742.png
#  extracting: Test/11752.png
#  extracting: Test/11753.png
#  extracting: Test/11761.png
#  extracting: Test/11766.png
#  extracting: Test/11771.png
#  extracting: Test/11778.png
#  extracting: Test/11779.png
#   inflating: Test/11789.png
#  extracting: Test/11790.png
#  extracting: Test/11791.png
#  extracting: Test/11792.png
#  extracting: Test/11798.png
#  extracting: Test/11801.png
#  extracting: Test/11804.png
#  extracting: Test/11806.png
#   inflating: Test/11808.png
#  extracting: Test/11810.png
#  extracting: Test/11812.png
#  extracting: Test/11814.png
#  extracting: Test/11827.png
#  extracting: Test/11846.png
#   inflating: Test/11847.png
#  extracting: Test/11848.png
#  extracting: Test/11851.png
#  extracting: Test/11858.png
#  extracting: Test/11863.png
#  extracting: Test/11873.png
#  extracting: Test/11882.png
#  extracting: Test/11887.png
#  extracting: Test/11889.png
#   inflating: Test/11902.png
#  extracting: Test/11917.png
#  extracting: Test/11924.png
#  extracting: Test/11928.png
#  extracting: Test/11931.png
#  extracting: Test/11938.png
#  extracting: Test/11951.png
#  extracting: Test/11952.png
#  extracting: Test/11967.png
#  extracting: Test/11988.png
#  extracting: Test/11990.png
#  extracting: Test/11993.png
#  extracting: Test/12001.png
#  extracting: Test/12011.png
#  extracting: Test/12021.png
#  extracting: Test/12056.png
#  extracting: Test/12057.png
#  extracting: Test/12060.png
#  extracting: Test/12062.png
#  extracting: Test/12076.png
#  extracting: Test/12089.png
#  extracting: Test/12093.png
#   inflating: Test/12105.png
#  extracting: Test/12109.png
#  extracting: Test/12121.png
#  extracting: Test/12127.png
#   inflating: Test/12162.png
#  extracting: Test/12186.png
#  extracting: Test/12210.png
#  extracting: Test/12223.png
#  extracting: Test/12235.png
#   inflating: Test/12243.png
#  extracting: Test/12248.png
#  extracting: Test/12291.png
#  extracting: Test/12293.png
#  extracting: Test/12330.png
#  extracting: Test/12341.png
#  extracting: Test/12342.png
#  extracting: Test/12345.png
#  extracting: Test/12349.png
#  extracting: Test/12352.png
#  extracting: Test/12362.png
#  extracting: Test/12374.png
#  extracting: Test/12380.png
#  extracting: Test/12382.png
#  extracting: Test/12385.png
#  extracting: Test/12386.png
#  extracting: Test/12407.png
#  extracting: Test/12422.png
#  extracting: Test/12423.png
#  extracting: Test/12432.png
#  extracting: Test/12441.png
#  extracting: Test/12448.png
#  extracting: Test/12454.png
#  extracting: Test/12456.png
#  extracting: Test/12478.png
#  extracting: Test/12496.png
#  extracting: Test/12498.png
#  extracting: Test/12511.png
#  extracting: Test/12517.png
#  extracting: Test/12524.png
#  extracting: Test/12527.png
#  extracting: Test/12528.png
#  extracting: Test/12569.png
#   inflating: Test/12572.png
#   inflating: Test/12577.png
#  extracting: Test/12584.png
#  extracting: Test/12611.png
#  extracting: Test/12614.png
#  extracting: Test/12626.png

# %%
# !ls
# Out:
# data.zip  sample_data  Test  Test_Label.csv  Train

# %%
pip install torchmetrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics
#   Downloading torchmetrics-0.9.0-py3-none-any.whl (418 kB)
#      |████████████████████████████████| 418 kB 13.9 MB/s
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.11.0+cu113)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.9)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.9.0

# %%
# Few imports

import torch
import torchvision

from torch.autograd import Variable
import matplotlib.pyplot as plt
import torch.utils.data as data
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import TensorDataset, DataLoader
import torch.optim as optim
import torch.nn as nn
from torchsummary import summary
from __future__ import print_function
from torch.utils.data import Dataset
from torchvision.io import read_image
from torch.autograd import Variable

import zipfile
import time
import numpy as np
import os
import matplotlib.pyplot as plt
import random
import argparse
import pandas as pd
import shutil
from PIL import Image

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import f1_score
from torchmetrics import F1Score

# %%
# # https://pytorch.org/docs/stable/notes/randomness.html

# # REPRODUCIBILITY
# # Controlling sources of randomness
def set_seed(RANDOM_SEED=333):
    torch.manual_seed(RANDOM_SEED)
    torch.cuda.manual_seed(RANDOM_SEED)
    torch.cuda.manual_seed_all(RANDOM_SEED) # if use multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(RANDOM_SEED)
    random.seed(RANDOM_SEED)
    os.environ['PYTHONHASHEED'] = str(RANDOM_SEED)
    
set_seed()

# torch.manual_seed(RANDOM_SEED)
# torch.cuda.manual_seed_all(RANDOM_SEED)

# random.seed(RANDOM_SEED)
# np.random.seed(RANDOM_SEED)

# def seed_worker(worker_id):
#     worker_seed = torch.initial_seed() % 2**32
#     np.random.seed(worker_seed)
#     random.seed(worker_seed)



# # reduced performance
# # torch.backends.cudnn.deterministic = True # torch.use_deterministic_algorithms(True)
# # torch.backends.cudnn.benchmark = False

# %%
# Before starting, clear the memory
torch.cuda.empty_cache()

# %%
# Define path of training data
train_data_path = "./Train"
data_transformer_stat = transforms.Compose([transforms.ToTensor()])
train_data_stat = torchvision.datasets.ImageFolder(root = train_data_path, transform = data_transformer_stat)
print(f"Number of training samples = {len(train_data_stat)}")
# Out:
# Number of training samples = 26010

# %%
# calculate the mean and standard deviation of train_data_stat

meanRGB = [np.mean(x.numpy(), axis=(1,2)) for x,_ in train_data_stat]
stdRGB = [np.std(x.numpy(), axis=(1,2)) for x,_ in train_data_stat]

meanR = np.mean([m[0] for m in meanRGB])
meanG = np.mean([m[1] for m in meanRGB])
meanB = np.mean([m[2] for m in meanRGB])

stdR = np.mean([s[0] for s in stdRGB])
stdG = np.mean([s[1] for s in stdRGB])
stdB = np.mean([s[2] for s in stdRGB])

print(meanR, meanG, meanB)
print(stdR, stdG, stdB)
# Out:
# 0.3429755 0.3128665 0.3212301
# 0.16778752 0.16812682 0.17826653

# %%
# Define the transformations. To begin with, we shall keep it minimum - only resizing the images and converting them to PyTorch tensors

data_transforms = transforms.Compose([
    transforms.Resize([48, 48]),
    transforms.ToTensor(),
    transforms.Normalize([meanR, meanG, meanB], [stdR, stdG, stdB])
    ])

# # Define transformations

data_transforms_rand = transforms.Compose([
  transforms.RandomRotation(degrees=15),
  transforms.RandomAutocontrast(),
  transforms.RandomAdjustSharpness(4),
  transforms.GaussianBlur(kernel_size=(3, 3), sigma=(0.2, 0.5)),
  transforms.Resize([48, 48]),  
  # transforms.CenterCrop(112*0.8),
  # transforms.Resize([112, 112]),
  transforms.ToTensor(),
  transforms.Normalize([meanR, meanG, meanB], [stdR, stdG, stdB])
  ])

# data_transforms_rand_old = transforms.Compose([
#   transforms.RandomRotation(degrees=15),
#   transforms.RandomAutocontrast(),
#   transforms.RandomAdjustSharpness(4),
#   transforms.Resize([112, 112]),
#   transforms.GaussianBlur(kernel_size=(7, 7), sigma=(2, 4)),
#   # transforms.CenterCrop(112*0.8),
#   # transforms.Resize([112, 112]),
#   transforms.ToTensor(),
#   transforms.Normalize([meanR, meanG, meanB], [stdR, stdG, stdB])
#   ])

# %%
print(os.getcwd())
os.listdir()
# Out:
# /content
# ['.config', 'Test', 'Train', 'Test_Label.csv', 'data.zip', 'sample_data']

# %%
# Defining hyperparameters

BATCH_SIZE = 256
learning_rate = 0.001
EPOCHS = 15
numClasses = 43

# %%
# Define path of training data

train_data_path = "./Train"
train_data_all = torchvision.datasets.ImageFolder(root = train_data_path, transform = data_transforms)
print(f"Number of training samples = {len(train_data_all)}")
# Out:
# Number of training samples = 26010

# %%
import sympy

mul_num = 10
lst_aug = [train_data_all]
for i in range(mul_num) :
  set_seed(i)
  rand_priime = sympy.randprime(0, 10000)
  set_seed(rand_priime)
  train_data_aug = torchvision.datasets.ImageFolder(root = train_data_path, transform = data_transforms_rand)
  lst_aug.append(train_data_aug)
set_seed()

# %%
train_data_aug = torch.utils.data.ConcatDataset(lst_aug)

# %%
# Divide data into training and validation (0.8 and 0.2)
ratio = 0.8
n_train_examples = int(len(train_data_aug) * ratio)
n_val_examples = len(train_data_aug) - n_train_examples

train_data, val_data = data.random_split(train_data_aug, [n_train_examples, n_val_examples])

print(f"Number of training samples = {len(train_data)}")
print(f"Number of validation samples = {len(val_data)}")
# Out:
# Number of training samples = 228888
# Number of validation samples = 57222

# %%
## 너무 오래걸림 ㅠ
# # Plot histogram for training and validation data


# train_hist = [0]*numClasses
# for i, value in enumerate(train_data):
#     data, label = value
#     train_hist[int(label)] += 1
    
# val_hist = [0]*numClasses
# for i, value in enumerate(val_data):
#     data, label = value
#     train_hist[int(label)] += 1

# plt.bar(range(numClasses), train_hist, label="train")
# # plt.bar(range(numClasses), val_hist, label="val")
# legend = plt.legend(loc='upper right', shadow=True)
# plt.title("Distribution Plot")
# plt.xlabel("Class ID")
# plt.ylabel("# of examples")

# plt.savefig("train_val_split.png", bbox_inches = 'tight', pad_inches=0.5)

# %%
# Create data loader for training and validation

# DataLoader(
#     train_dataset,
#     batch_size=batch_size,
#     num_workers=num_workers,
#     worker_init_fn=seed_worker
# )
train_aug_loader = DataLoader(train_data_aug, shuffle=True, batch_size = BATCH_SIZE)
train_loader = DataLoader(train_data, shuffle=True, batch_size = BATCH_SIZE)
val_loader = DataLoader(val_data, shuffle=True, batch_size = BATCH_SIZE)

# print(train_data_all[0][0].shape)
# print(train_data_all[0][1])
# print(len(train_data_all.samples))
# print(len(train_data_all.targets))
# print(len(train_data_all.classes))

# %%
# Test_Label
test_ans = pd.read_csv('Test_Label.csv')

# Create Folder
os.mkdir('./Test_ans/')
for i in range(43) : 
  path = './Test_ans/'+str(i)
  if os.path.isdir(path) : 
    # os.rmdir(path)
    print('existing' + path)
  else : 
    os.mkdir(path)

# file path move for answer data validation

for f in  test_ans.iterrows():
  filename = f[1]['Filename']
  src = './Test/'
  dir = './Test_ans/'+str(f[1]['ClassId']) + '/'
  shutil.copy(src + filename, dir + filename)

# %%
  # Define path of answer data
answer_data_path = "./Test_ans"
answer_data = torchvision.datasets.ImageFolder(root = answer_data_path, transform = data_transforms)
print(f"Number of answer samples = {len(answer_data)}")
answer_loader = DataLoader(answer_data, shuffle=False, batch_size = BATCH_SIZE)
# answer_loader = DataLoader(answer_data, shuffle=False, batch_size = BATCH_SIZE)
# print(answer_data.classes)
# print(answer_data.class_to_idx)
# Out:
# Number of answer samples = 8670

# %%
# Plot histogram for ans data

ans_hist = [0]*numClasses
for i, value in enumerate(answer_data):
    data, label = value
    ans_hist[label] += 1

plt.bar(range(numClasses), ans_hist, label="answer")
legend = plt.legend(loc='upper right', shadow=True)
plt.title("Distribution Plot")
plt.xlabel("Class ID")
plt.ylabel("# of examples")

plt.savefig("answer.png", bbox_inches = 'tight', pad_inches=0.5)

# %%
train_img = []  # imagefolder dataset 메모리에 올리기 위해 extract list
train_lab = []  
for (data, label) in train_data_aug :
  # print(label, data.shape)
  # print(data.numpy().shape)
  train_img.append(data.numpy())
  train_lab.append(label)
  # break
train_img = np.array(train_img)
train_lab = np.array(train_lab)
print(train_img.shape)
print(train_lab.shape)
train_img.reshape(len(train_lab), -1).shape
# Out:
# (286110, 3, 48, 48)
# (286110,)
# (286110, 6912)

# %%
from imblearn.over_sampling import SMOTE, ADASYN

smote = SMOTE(random_state = 0, k_neighbors = 5)
image_smote, label_smote = smote.fit_resample(train_img.reshape(len(train_lab), -1), train_lab)
s = train_img.shape
image_smote = image_smote.reshape(-1, s[1], s[2], s[3])
print(image_smote.shape)
print(label_smote.shape)
# Out:
# (595980, 3, 48, 48)
# (595980,)

# %%
# from torch.utils.data import TensorDataset, DataLoader

image_tensor = torch.tensor(image_smote, dtype=torch.float32)#.to("cuda:0")
label_tensor = torch.tensor(label_smote, dtype=torch.int64)#.to("cuda:0")
# from torch.utils.data import TensorDataset, DataLoader
train_ds = TensorDataset(image_tensor, label_tensor)
print(type(train_ds))
train_ds_loader = DataLoader(train_ds, shuffle=True, batch_size = BATCH_SIZE)
# Out:
# <class 'torch.utils.data.dataset.TensorDataset'>

# %%
# Plot histogram for training and validation data

train_hist = [0]*numClasses
for i, value in enumerate(train_ds):
    data, label = value
    # print(i, int(label), data.shape)
    # break
    train_hist[int(label)] += 1

plt.bar(range(numClasses), train_hist, label="train")
legend = plt.legend(loc='upper right', shadow=True)
plt.title("Distribution Plot")
plt.xlabel("Class ID")
plt.ylabel("# of examples")

plt.savefig("train_smote_split.png", bbox_inches = 'tight', pad_inches=0.5)

# %%
# for i, value in enumerate(train_ds):
#     data, label = value
#     print(label, data.shape)
#     break

# %% [markdown]
# #F1 Score

# %%
# class CustomImageDataset(Dataset):
#     def __init__(self, annotations_file, img_dir, transform=None, target_transform=None):
#         self.img_labels = pd.read_csv(annotations_file
#                                     #   , names=['Filename', 'ClassId']
#                                       )
#         self.img_dir = img_dir
#         self.transform = transform
#         self.target_transform = target_transform

#     def __len__(self):
#         return len(self.img_labels)

#     def __getitem__(self, idx):
#         img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
#         image = Image.open(img_path)
#         label = self.img_labels.iloc[idx, 1]
#         if self.transform:
#             image = self.transform(image)
#         if self.target_transform:
#             label = self.target_transform(label)
#         return image, label

# num = range(nclasses) # 43
# torch_class_to_real_class = [str(i) for i in num]
# torch_class_to_real_class = sorted(torch_class_to_real_class)
# torch_class_to_real_class = [int(torch_class_to_real_class[i]) for i in num]

# def evaluate_test(model, loader, torch_class_to_real_class):
#     model.eval()
#     y_true_list = []
#     y_pred_list_before_mapping = []
#     with torch.no_grad():
#         for (images, labels) in test_dataloader:
#             y_true_list.append(labels)
#             images = images.cuda()

#             output = model(images)
            
#             y_pred_tags = output.data.max(1, keepdim=True)[1]
#             y_pred_tags = y_pred_tags.cpu().numpy().reshape(-1)
#             y_pred_list_before_mapping.append(y_pred_tags)

    
#     y_true_list = np.concatenate(y_true_list)
#     total_y_pred_list_before_mapping = np.concatenate(y_pred_list_before_mapping)
#     y_pred_list = [torch_class_to_real_class[torch_class] for torch_class in total_y_pred_list_before_mapping]

#     macro_f1 = f1_score(
#         y_true = y_true_list,
#         y_pred = y_pred_list,
#         average = 'macro')
    
#     return macro_f1, y_pred_list

# %%
# ans_file_name = "Test_Label.csv"
# img_dir = "Test"
# test_transform = transforms.Compose([
#     transforms.Resize([48, 48]),
#     transforms.ToTensor(),
#     transforms.Normalize((0.3337, 0.3064, 0.3171), ( 0.2672, 0.2564, 0.2629)) # need to change mean / std 
# ])
# test_batch_size = 1_000

# test_data = CustomImageDataset(ans_file_name, img_dir, test_transform)
# test_dataloader = torch.utils.data.DataLoader(test_data, shuffle=False, batch_size = test_batch_size)

# %%
# # curr_score == F1 score  |  curr_y_pred_list : perd_resutl
# curr_score, curr_y_pred_list = evaluate_test(model, test_dataloader, torch_class_to_real_class

# %% [markdown]
# # MicronNet

# %%
nclasses = 43 # GTSRB as 43 classes

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 1, kernel_size=1)
        self.conv2 = nn.Conv2d(1, 29, kernel_size=5)
        self.maxpool2 = nn.MaxPool2d(3, stride=2 , ceil_mode=True)
        self.conv3 = nn.Conv2d(29, 59, kernel_size=3)
        self.maxpool3 = nn.MaxPool2d(3, stride=2 , ceil_mode=True)
        self.conv4 = nn.Conv2d(59, 74, kernel_size=3)
        self.maxpool4 = nn.MaxPool2d(3, stride=2 , ceil_mode=True)
        self.conv2_drop = nn.Dropout2d()
        self.conv3_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(1184, 300)
        self.fc2 = nn.Linear(300, nclasses)
        self.conv0_bn = nn.BatchNorm2d(3)
        self.conv1_bn = nn.BatchNorm2d(1)
        self.conv2_bn = nn.BatchNorm2d(29)
        self.conv3_bn = nn.BatchNorm2d(59)
        self.conv4_bn = nn.BatchNorm2d(74)
        self.dense1_bn = nn.BatchNorm1d(300)
    def forward(self, x):
        x =  F.relu(self.conv1_bn(self.conv1(self.conv0_bn(x))))
        x = F.relu(self.conv2_bn(self.conv2(x)))
        x = F.relu(self.conv3_bn(self.conv3( self.maxpool2(x))))
        x = F.relu(self.conv4_bn(self.conv4( self.maxpool3(x))))
        x = self.maxpool4(x)        
        x = x.view(-1, 1184)
        x = F.relu(self.fc1(x))
        x = self.dense1_bn(x)
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        x = F.dropout(x, training=self.training)
        return F.log_softmax(x, -1)

# %%
epochs = 1000
# epochs = 10000
batch_size = 50
seed = 1
log_interval=512
data = "data"
torch.manual_seed(1)
lr =0.007
momentum = 0.9
# step = 1000
step = 50
decay =  0.9996
l2_norm = 0.00001
cuda = True
resume = False
# These may change as described in paper

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = Net()
if  cuda: 
    model.to(device)

if resume :
    state_dict = torch.load("model_28.pth")
    model.load_state_dict(state_dict)

# %%
# print(len(answer_loader.dataset))
# print(len(answer_loader))
# for i, (data, target) in enumerate(answer_loader):
#   print(i)

# %%
# https://stackoverflow.com/questions/65318064/can-i-trainoptimize-on-f1-score-loss-with-pytorch
# https://stackoverflow.com/questions/53354176/how-to-use-f-score-as-error-function-to-train-neural-networks
# loss <-- F-Measure as the Error Function to Train Neural Networks 
#

def validation():
    model.eval()
    validation_loss = 0
    correct = 0
    f1_score = 0
    f1 = F1Score(num_classes=nclasses).to(device) # .to(device)
    with torch.no_grad():
        start_time = time.monotonic()
        for data, target in answer_loader:
            # data, target = Variable(data), Variable(target)
            data = data.to(device)
            target =target.to(device)
            output = model(data)
            validation_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
            pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.data.view_as(pred)).cpu().sum()
            f1_score += f1(pred, target)
        validation_loss /= len(answer_loader.dataset)
        f1_score /= len(answer_loader)
        end_time = time.monotonic()
        print(f"\nValidation set: Average loss: {format(validation_loss, '.4f')}, f1 score : {format(f1_score, '.4f')}, Accuracy: {correct}/{len(answer_loader.dataset)} ({format(100. * correct / len(answer_loader.dataset), '.3f')}%)", end=' ')
        print(", Time = %.2f seconds" % (end_time - start_time))
    return validation_loss, f1_score


def train(epoch , train_loader):
    model.train()
    start_time = time.monotonic()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = Variable(data), Variable(target)
        data = data.to(device)
        target = target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target).cuda()
        loss.backward()
        optimizer.step()
        # if batch_idx % log_interval == 0: len(train_loader)
        if batch_idx == len(train_loader)-1 :
            # print(f"Train Epoch: {epoch}\t[{batch_idx * len(data)}/{len(train_loader.dataset)}\t({format(100. * batch_idx / len(train_loader),'.3f')}%)]\tLoss: {format(loss.item(),'.6f')}")
            print(f"Train Epoch: {epoch}\tLoss: {format(loss.item(),'.6f')}", end=' ')
    end_time = time.monotonic()
    print("Time = %.2f seconds" % (end_time - start_time), end=' ')

# %%
# # https://stackoverflow.com/questions/65318064/can-i-trainoptimize-on-f1-score-loss-with-pytorch
# # https://stackoverflow.com/questions/53354176/how-to-use-f-score-as-error-function-to-train-neural-networks
# # loss <-- F-Measure as the Error Function to Train Neural Networks 
# #

# def validation():
#     model.eval()
#     validation_loss = 0
#     correct = 0
#     with torch.no_grad():
#         for data, target in answer_loader:
#             # data, target = Variable(data), Variable(target)
#             data = data.to(device)
#             target =target.to(device)
#             output = model(data)
#             validation_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
#             pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
#             correct += pred.eq(target.data.view_as(pred)).cpu().sum()
#         validation_loss /= len(val_loader.dataset)
#         print(f"\nValidation set: Average loss: {format(validation_loss, '.4f')}, Accuracy: {correct}/{len(answer_loader.dataset)} ({format(100. * correct / len(answer_loader.dataset), '.0f')}%)\n")
#     return validation_loss


# def train(epoch , train_loader):
#     model.train()
#     for batch_idx, (data, target) in enumerate(train_loader):
#         data, target = Variable(data), Variable(target)
#         data = data.to(device)
#         target = target.to(device)
#         optimizer.zero_grad()
#         output = model(data)
#         loss = F.nll_loss(output, target).cuda()
#         loss.backward()
#         optimizer.step()
#         if batch_idx % log_interval == 0:
#             print(f"Train Epoch: {epoch}\t[{batch_idx * len(data)}/{len(train_loader.dataset)}\t({format(100. * batch_idx / len(train_loader),'.3f')}%)]\tLoss: {format(loss.item(),'.6f')}")

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=lr , momentum=momentum, weight_decay=l2_norm, nesterov=True)
scheduler = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=decay)
# train_ds_loader train_aug_loader
# temp = 10
temp_f1 = 0.9
epochs = 300
best_model_epoch = 0
for epoch in range(1, epochs):
    train(epoch, train_ds_loader)
    val, f1 = validation()
    if epoch % step == 0 :
        scheduler.step()
    if f1 > temp_f1 : 
        temp_f1 = f1
        best_model_epoch = epoch
        model_file = 'model_' + str(epoch) + '.pth'
        torch.save(model.state_dict(), model_file)
        print('\nSaved model to ' + model_file + '. You can run `python evaluate.py ' + model_file + '` to generate the Kaggle formatted csv file')
    # if val < temp : 
    #     temp = val
    #     model_file = 'model_' + str(epoch) + '.pth'
    #     torch.save(model.state_dict(), model_file)
    #     print('\nSaved model to ' + model_file + '. You can run `python evaluate.py ' + model_file + '` to generate the Kaggle formatted csv file')
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# Train Epoch: 1	Loss: 2.188654 Time = 32.19 seconds
# Validation set: Average loss: 0.7907, f1 score : 0.8150, Accuracy: 7067/8670 (81.511%) , Time = 5.51 seconds
# Train Epoch: 2	Loss: 2.064713 Time = 32.17 seconds
# Validation set: Average loss: 0.1749, f1 score : 0.9666, Accuracy: 8379/8670 (96.644%) , Time = 5.47 seconds
#
# Saved model to model_2.pth. You can run `python evaluate.py model_2.pth` to generate the Kaggle formatted csv file
# Train Epoch: 3	Loss: 1.090211 Time = 32.19 seconds
# Validation set: Average loss: 0.2085, f1 score : 0.9648, Accuracy: 8364/8670 (96.471%) , Time = 5.50 seconds
# Train Epoch: 4	Loss: 1.354854 Time = 32.53 seconds
# Validation set: Average loss: 0.1387, f1 score : 0.9721, Accuracy: 8427/8670 (97.197%) , Time = 5.37 seconds
#
# Saved model to model_4.pth. You can run `python evaluate.py model_4.pth` to generate the Kaggle formatted csv file
# Train Epoch: 5	Loss: 0.812928 Time = 32.51 seconds
# Validation set: Average loss: 0.1240, f1 score : 0.9761, Accuracy: 8462/8670 (97.601%) , Time = 5.30 seconds
#
# Saved model to model_5.pth. You can run `python evaluate.py model_5.pth` to generate the Kaggle formatted csv file
# Train Epoch: 6	Loss: 1.379233 Time = 31.76 seconds
# Validation set: Average loss: 1.3488, f1 score : 0.6821, Accuracy: 5911/8670 (68.178%) , Time = 5.25 seconds
# Train Epoch: 7	Loss: 2.584019 Time = 31.79 seconds
# Validation set: Average loss: 0.1013, f1 score : 0.9793, Accuracy: 8490/8670 (97.924%) , Time = 5.30 seconds
#
# Saved model to model_7.pth. You can run `python evaluate.py model_7.pth` to generate the Kaggle formatted csv file
# Train Epoch: 8	Loss: 1.780654 Time = 31.88 seconds
# Validation set: Average loss: 0.1204, f1 score : 0.9740, Accuracy: 8444/8670 (97.393%) , Time = 5.29 seconds
# Train Epoch: 9	Loss: 1.573625 Time = 31.91 seconds
# Validation set: Average loss: 0.1015, f1 score : 0.9768, Accuracy: 8468/8670 (97.670%) , Time = 5.21 seconds
# Train Epoch: 10	Loss: 2.103806 Time = 31.83 seconds
# Validation set: Average loss: 0.0988, f1 score : 0.9774, Accuracy: 8473/8670 (97.728%) , Time = 5.27 seconds
# Train Epoch: 11	Loss: 1.297627 Time = 31.93 seconds
# Validation set: Average loss: 0.0935, f1 score : 0.9796, Accuracy: 8493/8670 (97.958%) , Time = 5.40 seconds
#
# Saved model to model_11.pth. You can run `python evaluate.py model_11.pth` to generate the Kaggle formatted csv file
# Train Epoch: 12	Loss: 1.567628 Time = 31.85 seconds
# Validation set: Average loss: 0.0872, f1 score : 0.9789, Accuracy: 8486/8670 (97.878%) , Time = 5.30 seconds
# Train Epoch: 13	Loss: 1.577311 Time = 31.93 seconds
# Validation set: Average loss: 0.0785, f1 score : 0.9825, Accuracy: 8518/8670 (98.247%) , Time = 5.31 seconds
#
# Saved model to model_13.pth. You can run `python evaluate.py model_13.pth` to generate the Kaggle formatted csv file
# Train Epoch: 14	Loss: 1.798963 Time = 31.94 seconds
# Validation set: Average loss: 0.0722, f1 score : 0.9833, Accuracy: 8525/8670 (98.328%) , Time = 5.28 seconds
#
# Saved model to model_14.pth. You can run `python evaluate.py model_14.pth` to generate the Kaggle formatted csv file
# Train Epoch: 15	Loss: 1.285353 Time = 31.91 seconds
# Validation set: Average loss: 0.0765, f1 score : 0.9827, Accuracy: 8519/8670 (98.258%) , Time = 5.32 seconds
# Train Epoch: 16	Loss: 1.286599 Time = 31.87 seconds
# Validation set: Average loss: 3.1115, f1 score : 0.3076, Accuracy: 2677/8670 (30.877%) , Time = 5.22 seconds
# Train Epoch: 17	Loss: 2.035534 Time = 31.92 seconds
# Validation set: Average loss: 0.1178, f1 score : 0.9737, Accuracy: 8441/8670 (97.359%) , Time = 5.23 seconds
# Train Epoch: 18	Loss: 1.537890 Time = 31.93 seconds
# Validation set: Average loss: 0.0871, f1 score : 0.9805, Accuracy: 8500/8670 (98.039%) , Time = 5.27 seconds
# Train Epoch: 19	Loss: 1.816433 Time = 31.87 seconds
# Validation set: Average loss: 0.0911, f1 score : 0.9776, Accuracy: 8475/8670 (97.751%) , Time = 5.40 seconds
# Train Epoch: 20	Loss: 2.080691 Time = 32.02 seconds
# Validation set: Average loss: 0.0863, f1 score : 0.9799, Accuracy: 8495/8670 (97.982%) , Time = 5.32 seconds
# Train Epoch: 21	Loss: 1.531678 Time = 31.87 seconds
# Validation set: Average loss: 0.0891, f1 score : 0.9799, Accuracy: 8495/8670 (97.982%) , Time = 5.31 seconds
# Train Epoch: 22	Loss: 1.846118 Time = 31.90 seconds
# Validation set: Average loss: 0.0844, f1 score : 0.9804, Accuracy: 8499/8670 (98.028%) , Time = 5.32 seconds
# Train Epoch: 23	Loss: 0.739591 Time = 31.91 seconds
# Validation set: Average loss: 0.0791, f1 score : 0.9808, Accuracy: 8503/8670 (98.074%) , Time = 5.34 seconds
# Train Epoch: 24	Loss: 1.837552 Time = 31.93 seconds
# Validation set: Average loss: 0.0828, f1 score : 0.9804, Accuracy: 8499/8670 (98.028%) , Time = 5.26 seconds
# Train Epoch: 25	Loss: 1.789508 Time = 31.97 seconds
# Validation set: Average loss: 0.0783, f1 score : 0.9817, Accuracy: 8511/8670 (98.166%) , Time = 5.30 seconds
# Train Epoch: 26	Loss: 1.523802 Time = 31.77 seconds
# Validation set: Average loss: 0.0739, f1 score : 0.9813, Accuracy: 8507/8670 (98.120%) , Time = 5.34 seconds
# Train Epoch: 27	Loss: 2.066206 Time = 31.77 seconds
# Validation set: Average loss: 0.0755, f1 score : 0.9821, Accuracy: 8514/8670 (98.201%) , Time = 5.37 seconds
# Train Epoch: 28	Loss: 1.031784 Time = 31.84 seconds
# Validation set: Average loss: 0.0757, f1 score : 0.9828, Accuracy: 8520/8670 (98.270%) , Time = 5.29 seconds
# Train Epoch: 29	Loss: 1.711843 Time = 31.77 seconds
# Validation set: Average loss: 0.3146, f1 score : 0.9242, Accuracy: 8010/8670 (92.388%) , Time = 5.31 seconds
# Train Epoch: 30	Loss: 1.813689 Time = 32.04 seconds
# Validation set: Average loss: 0.0820, f1 score : 0.9812, Accuracy: 8506/8670 (98.108%) , Time = 5.21 seconds
# Train Epoch: 31	Loss: 2.030497 Time = 31.88 seconds
# Validation set: Average loss: 0.0742, f1 score : 0.9814, Accuracy: 8508/8670 (98.131%) , Time = 5.28 seconds
# Train Epoch: 32	Loss: 1.550465 Time = 31.86 seconds
# Validation set: Average loss: 0.0809, f1 score : 0.9810, Accuracy: 8505/8670 (98.097%) , Time = 5.37 seconds
# Train Epoch: 33	Loss: 1.533574 Time = 32.25 seconds
# Validation set: Average loss: 0.0739, f1 score : 0.9837, Accuracy: 8528/8670 (98.362%) , Time = 5.27 seconds
#
# Saved model to model_33.pth. You can run `python evaluate.py model_33.pth` to generate the Kaggle formatted csv file
# Train Epoch: 34	Loss: 1.592755 Time = 32.10 seconds
# Validation set: Average loss: 0.3649, f1 score : 0.9202, Accuracy: 7975/8670 (91.984%) , Time = 5.32 seconds
# Train Epoch: 35	Loss: 0.511375 Time = 31.72 seconds
# Validation set: Average loss: 0.0729, f1 score : 0.9829, Accuracy: 8521/8670 (98.281%) , Time = 5.22 seconds
# Train Epoch: 36	Loss: 1.772255 Time = 31.67 seconds
# Validation set: Average loss: 0.0733, f1 score : 0.9829, Accuracy: 8521/8670 (98.281%) , Time = 5.22 seconds
# Train Epoch: 37	Loss: 1.793296 Time = 31.79 seconds
# Validation set: Average loss: 0.2383, f1 score : 0.9412, Accuracy: 8159/8670 (94.106%) , Time = 5.20 seconds
# Train Epoch: 38	Loss: 2.538970 Time = 31.80 seconds
# Validation set: Average loss: 0.2227, f1 score : 0.9469, Accuracy: 8208/8670 (94.671%) , Time = 5.32 seconds
# Train Epoch: 39	Loss: 2.209123 Time = 31.87 seconds
# Validation set: Average loss: 0.0727, f1 score : 0.9837, Accuracy: 8528/8670 (98.362%) , Time = 5.24 seconds
# Train Epoch: 40	Loss: 1.820197 Time = 31.68 seconds
# Validation set: Average loss: 0.0692, f1 score : 0.9844, Accuracy: 8534/8670 (98.431%) , Time = 5.14 seconds
#
# Saved model to model_40.pth. You can run `python evaluate.py model_40.pth` to generate the Kaggle formatted csv file
# Train Epoch: 41	Loss: 2.299770 Time = 32.07 seconds
# Validation set: Average loss: 0.0721, f1 score : 0.9830, Accuracy: 8522/8670 (98.293%) , Time = 5.42 seconds
# Train Epoch: 42	Loss: 1.973268 Time = 31.97 seconds
# Validation set: Average loss: 0.0690, f1 score : 0.9838, Accuracy: 8529/8670 (98.374%) , Time = 5.44 seconds
# Train Epoch: 43	Loss: 1.278018 Time = 32.15 seconds
# Validation set: Average loss: 0.0644, f1 score : 0.9854, Accuracy: 8543/8670 (98.535%) , Time = 5.45 seconds
#
# Saved model to model_43.pth. You can run `python evaluate.py model_43.pth` to generate the Kaggle formatted csv file
# Train Epoch: 44	Loss: 1.533506 Time = 32.04 seconds
# Validation set: Average loss: 0.0665, f1 score : 0.9843, Accuracy: 8533/8670 (98.420%) , Time = 5.41 seconds
# Train Epoch: 45	Loss: 1.274305 Time = 32.12 seconds
# Validation set: Average loss: 0.0725, f1 score : 0.9825, Accuracy: 8518/8670 (98.247%) , Time = 5.50 seconds
# Train Epoch: 46	Loss: 1.524243 Time = 32.15 seconds
# Validation set: Average loss: 0.0652, f1 score : 0.9855, Accuracy: 8544/8670 (98.547%) , Time = 5.48 seconds
#
# Saved model to model_46.pth. You can run `python evaluate.py model_46.pth` to generate the Kaggle formatted csv file
# Train Epoch: 47	Loss: 0.772570 Time = 32.23 seconds
# Validation set: Average loss: 0.0678, f1 score : 0.9838, Accuracy: 8529/8670 (98.374%) , Time = 5.49 seconds
# Train Epoch: 48	Loss: 1.552959 Time = 32.21 seconds
# Validation set: Average loss: 0.0685, f1 score : 0.9835, Accuracy: 8526/8670 (98.339%) , Time = 5.43 seconds
# Train Epoch: 49	Loss: 1.004131 Time = 32.13 seconds
# Validation set: Average loss: 0.0680, f1 score : 0.9838, Accuracy: 8529/8670 (98.374%) , Time = 5.37 seconds
# Train Epoch: 50	Loss: 1.770023 Time = 32.10 seconds
# Validation set: Average loss: 0.0684, f1 score : 0.9835, Accuracy: 8526/8670 (98.339%) , Time = 5.45 seconds
# Train Epoch: 51	Loss: 1.520871 Time = 32.26 seconds
# Validation set: Average loss: 0.0699, f1 score : 0.9829, Accuracy: 8521/8670 (98.281%) , Time = 5.46 seconds
# Train Epoch: 52	Loss: 1.325888 Time = 32.26 seconds
# Validation set: Average loss: 0.0721, f1 score : 0.9827, Accuracy: 8519/8670 (98.258%) , Time = 5.45 seconds
# Train Epoch: 53	Loss: 2.239925 Time = 32.12 seconds
# Validation set: Average loss: 0.0669, f1 score : 0.9833, Accuracy: 8525/8670 (98.328%) , Time = 5.49 seconds
# Train Epoch: 54	Loss: 1.537453 Time = 32.37 seconds
# Validation set: Average loss: 0.0730, f1 score : 0.9822, Accuracy: 8515/8670 (98.212%) , Time = 5.52 seconds
# Train Epoch: 55	Loss: 1.818204 Time = 32.28 seconds
# Validation set: Average loss: 0.0717, f1 score : 0.9835, Accuracy: 8526/8670 (98.339%) , Time = 5.46 seconds
# Train Epoch: 56	Loss: 0.767752 Time = 32.27 seconds
# Validation set: Average loss: 0.0689, f1 score : 0.9832, Accuracy: 8524/8670 (98.316%) , Time = 5.42 seconds
# Train Epoch: 57	Loss: 1.583108 Time = 32.27 seconds
# Validation set: Average loss: 0.0677, f1 score : 0.9838, Accuracy: 8529/8670 (98.374%) , Time = 5.46 seconds
# Train Epoch: 58	Loss: 1.033149 Time = 32.22 seconds
# Validation set: Average loss: 0.0675, f1 score : 0.9839, Accuracy: 8530/8670 (98.385%) , Time = 5.38 seconds
# Train Epoch: 59	Loss: 1.555980 Time = 31.97 seconds
# Validation set: Average loss: 0.0705, f1 score : 0.9837, Accuracy: 8528/8670 (98.362%) , Time = 5.49 seconds
# Train Epoch: 60	Loss: 1.312464 Time = 32.19 seconds
# Validation set: Average loss: 0.0676, f1 score : 0.9838, Accuracy: 8529/8670 (98.374%) , Time = 5.36 seconds
# Train Epoch: 61	Loss: 1.317494 Time = 32.20 seconds
# Validation set: Average loss: 0.0691, f1 score : 0.9837, Accuracy: 8528/8670 (98.362%) , Time = 5.48 seconds
# Train Epoch: 62	Loss: 1.501487 Time = 32.11 seconds
# Validation set: Average loss: 0.0679, f1 score : 0.9833, Accuracy: 8525/8670 (98.328%) , Time = 5.34 seconds
# Train Epoch: 63	Loss: 2.200968 Time = 31.89 seconds
# Validation set: Average loss: 0.0690, f1 score : 0.9837, Accuracy: 8528/8670 (98.362%) , Time = 5.37 seconds
# Train Epoch: 64	Loss: 1.824136 Time = 32.05 seconds
# Validation set: Average loss: 0.0651, f1 score : 0.9838, Accuracy: 8529/8670 (98.374%) , Time = 5.38 seconds
# Train Epoch: 65	Loss: 1.028809 Time = 31.82 seconds
# Validation set: Average loss: 0.0635, f1 score : 0.9848, Accuracy: 8538/8670 (98.478%) , Time = 5.32 seconds
# Train Epoch: 66	Loss: 1.786974 Time = 32.02 seconds
# Validation set: Average loss: 0.0675, f1 score : 0.9832, Accuracy: 8524/8670 (98.316%) , Time = 5.37 seconds
# Train Epoch: 67	Loss: 1.574054 Time = 31.96 seconds
# Validation set: Average loss: 0.0636, f1 score : 0.9843, Accuracy: 8533/8670 (98.420%) , Time = 5.29 seconds
# Train Epoch: 68	Loss: 1.530984 Time = 31.90 seconds
# Validation set: Average loss: 0.0690, f1 score : 0.9835, Accuracy: 8526/8670 (98.339%) , Time = 5.32 seconds
# Train Epoch: 69	Loss: 1.792639 Time = 31.93 seconds
# Validation set: Average loss: 0.0664, f1 score : 0.9837, Accuracy: 8528/8670 (98.362%) , Time = 5.32 seconds
# Train Epoch: 70	Loss: 1.800547 Time = 31.91 seconds
# Validation set: Average loss: 0.0682, f1 score : 0.9836, Accuracy: 8527/8670 (98.351%) , Time = 5.33 seconds
# Train Epoch: 71	Loss: 0.772350 Time = 32.03 seconds
# Validation set: Average loss: 0.0716, f1 score : 0.9835, Accuracy: 8526/8670 (98.339%) , Time = 5.34 seconds
# Train Epoch: 72	Loss: 2.340533 Time = 31.89 seconds
# Validation set: Average loss: 0.0687, f1 score : 0.9843, Accuracy: 8533/8670 (98.420%) , Time = 5.41 seconds
# Train Epoch: 73	Loss: 1.594038 Time = 31.92 seconds
# Validation set: Average loss: 0.0807, f1 score : 0.9797, Accuracy: 8493/8670 (97.958%) , Time = 5.33 seconds
# Train Epoch: 74	Loss: 1.816306 Time = 31.83 seconds
# Validation set: Average loss: 0.0667, f1 score : 0.9852, Accuracy: 8541/8670 (98.512%) , Time = 5.34 seconds
# Train Epoch: 75	Loss: 1.543328 Time = 31.87 seconds
# Validation set: Average loss: 0.0724, f1 score : 0.9824, Accuracy: 8517/8670 (98.235%) , Time = 5.28 seconds
# Train Epoch: 76	Loss: 0.773914 Time = 31.98 seconds
# Validation set: Average loss: 0.0704, f1 score : 0.9824, Accuracy: 8517/8670 (98.235%) , Time = 5.24 seconds
# Train Epoch: 77	Loss: 1.223579 Time = 31.87 seconds
# Validation set: Average loss: 0.0653, f1 score : 0.9851, Accuracy: 8540/8670 (98.501%) , Time = 5.24 seconds
# Train Epoch: 78	Loss: 1.530237 Time = 31.77 seconds
# Validation set: Average loss: 0.0639, f1 score : 0.9845, Accuracy: 8535/8670 (98.443%) , Time = 5.29 seconds
# Train Epoch: 79	Loss: 2.048354 Time = 31.71 seconds
# Validation set: Average loss: 0.0653, f1 score : 0.9841, Accuracy: 8532/8670 (98.408%) , Time = 5.18 seconds
# Train Epoch: 80	Loss: 1.836572 Time = 31.69 seconds
# Validation set: Average loss: 0.0689, f1 score : 0.9843, Accuracy: 8533/8670 (98.420%) , Time = 5.28 seconds
# Train Epoch: 81	Loss: 1.244337 Time = 31.58 seconds
# Validation set: Average loss: 0.0691, f1 score : 0.9845, Accuracy: 8535/8670 (98.443%) , Time = 5.16 seconds
# Train Epoch: 82	Loss: 1.314832 Time = 31.66 seconds
# Validation set: Average loss: 0.0714, f1 score : 0.9823, Accuracy: 8516/8670 (98.224%) , Time = 5.19 seconds
# Train Epoch: 83	Loss: 2.055904 Time = 31.63 seconds
# Validation set: Average loss: 0.0683, f1 score : 0.9832, Accuracy: 8524/8670 (98.316%) , Time = 5.14 seconds
# Train Epoch: 84	Loss: 1.798134 Time = 31.58 seconds
# Validation set: Average loss: 0.0710, f1 score : 0.9837, Accuracy: 8528/8670 (98.362%) , Time = 5.13 seconds
# Train Epoch: 85	Loss: 1.569027 Time = 31.57 seconds
# Validation set: Average loss: 0.0703, f1 score : 0.9833, Accuracy: 8525/8670 (98.328%) , Time = 5.19 seconds
# Train Epoch: 86	Loss: 1.266584 Time = 31.68 seconds
# Validation set: Average loss: 0.0647, f1 score : 0.9844, Accuracy: 8534/8670 (98.431%) , Time = 5.28 seconds
# Train Epoch: 87	Loss: 1.081649 Time = 31.66 seconds
# Validation set: Average loss: 0.0635, f1 score : 0.9854, Accuracy: 8543/8670 (98.535%) , Time = 5.23 seconds
# Train Epoch: 88	Loss: 1.052698 Time = 31.78 seconds
# Validation set: Average loss: 0.0643, f1 score : 0.9848, Accuracy: 8538/8670 (98.478%) , Time = 5.24 seconds
# Train Epoch: 89	Loss: 0.813711 Time = 31.74 seconds
# Validation set: Average loss: 0.0671, f1 score : 0.9847, Accuracy: 8537/8670 (98.466%) , Time = 5.23 seconds
# Train Epoch: 90	Loss: 0.769102 Time = 31.71 seconds
# Validation set: Average loss: 0.0634, f1 score : 0.9853, Accuracy: 8542/8670 (98.524%) , Time = 5.22 seconds
# Train Epoch: 91	Loss: 0.762523 Time = 31.77 seconds
# Validation set: Average loss: 0.0622, f1 score : 0.9852, Accuracy: 8541/8670 (98.512%) , Time = 5.17 seconds
# Train Epoch: 92	Loss: 1.075653 Time = 31.71 seconds
# Validation set: Average loss: 0.0645, f1 score : 0.9849, Accuracy: 8539/8670 (98.489%) , Time = 5.30 seconds
# Train Epoch: 93	Loss: 0.748766 Time = 31.73 seconds
# Validation set: Average loss: 0.0620, f1 score : 0.9856, Accuracy: 8545/8670 (98.558%) , Time = 5.33 seconds
#
# Saved model to model_93.pth. You can run `python evaluate.py model_93.pth` to generate the Kaggle formatted csv file
# Train Epoch: 94	Loss: 1.810506 Time = 31.83 seconds
# Validation set: Average loss: 0.0626, f1 score : 0.9855, Accuracy: 8544/8670 (98.547%) , Time = 5.26 seconds
# Train Epoch: 95	Loss: 2.279709 Time = 31.80 seconds
# Validation set: Average loss: 0.0638, f1 score : 0.9851, Accuracy: 8540/8670 (98.501%) , Time = 5.25 seconds
# Train Epoch: 96	Loss: 1.595679 Time = 31.68 seconds
# Validation set: Average loss: 0.0739, f1 score : 0.9837, Accuracy: 8528/8670 (98.362%) , Time = 5.19 seconds
# Train Epoch: 97	Loss: 1.493420 Time = 31.88 seconds
# Validation set: Average loss: 0.0657, f1 score : 0.9848, Accuracy: 8538/8670 (98.478%) , Time = 5.43 seconds
# Train Epoch: 98	Loss: 1.561797 Time = 31.99 seconds
# Validation set: Average loss: 0.2615, f1 score : 0.9488, Accuracy: 8224/8670 (94.856%) , Time = 5.39 seconds
# Train Epoch: 99	Loss: 2.020234 Time = 31.94 seconds
# Validation set: Average loss: 0.0683, f1 score : 0.9835, Accuracy: 8526/8670 (98.339%) , Time = 5.35 seconds
# Train Epoch: 100	Loss: 1.748852 Time = 32.08 seconds
# Validation set: Average loss: 0.0641, f1 score : 0.9847, Accuracy: 8537/8670 (98.466%) , Time = 5.37 seconds
# Train Epoch: 101	Loss: 1.254126 Time = 31.93 seconds
# Validation set: Average loss: 0.0660, f1 score : 0.9841, Accuracy: 8532/8670 (98.408%) , Time = 5.33 seconds
# Train Epoch: 102	Loss: 1.750437 Time = 31.88 seconds
# Validation set: Average loss: 0.0651, f1 score : 0.9844, Accuracy: 8534/8670 (98.431%) , Time = 5.31 seconds
# Train Epoch: 103	Loss: 2.034470 Time = 31.95 seconds
# Validation set: Average loss: 0.0686, f1 score : 0.9840, Accuracy: 8531/8670 (98.397%) , Time = 5.30 seconds
# Train Epoch: 104	Loss: 1.793084 Time = 31.98 seconds
# Validation set: Average loss: 0.0674, f1 score : 0.9843, Accuracy: 8533/8670 (98.420%) , Time = 5.31 seconds
# Train Epoch: 105	Loss: 1.325039 Time = 31.86 seconds
# Validation set: Average loss: 0.0685, f1 score : 0.9832, Accuracy: 8524/8670 (98.316%) , Time = 5.44 seconds
# Train Epoch: 106	Loss: 1.577164 Time = 31.81 seconds
# Validation set: Average loss: 0.0671, f1 score : 0.9838, Accuracy: 8529/8670 (98.374%) , Time = 5.41 seconds
# Train Epoch: 107	Loss: 1.286318 Time = 32.05 seconds
# Validation set: Average loss: 0.0680, f1 score : 0.9830, Accuracy: 8522/8670 (98.293%) , Time = 5.41 seconds
# Train Epoch: 108	Loss: 2.264316 Time = 32.00 seconds
# Validation set: Average loss: 0.0669, f1 score : 0.9840, Accuracy: 8531/8670 (98.397%) , Time = 5.37 seconds
# Train Epoch: 109	Loss: 2.033908 Time = 32.11 seconds
# Validation set: Average loss: 0.0656, f1 score : 0.9841, Accuracy: 8532/8670 (98.408%) , Time = 5.46 seconds
# Train Epoch: 110	Loss: 1.499471 Time = 32.10 seconds
# Validation set: Average loss: 0.0635, f1 score : 0.9848, Accuracy: 8538/8670 (98.478%) , Time = 5.36 seconds
# Train Epoch: 111	Loss: 2.311729 Time = 31.99 seconds
# Validation set: Average loss: 0.0665, f1 score : 0.9836, Accuracy: 8527/8670 (98.351%) , Time = 5.40 seconds
# Train Epoch: 112	Loss: 1.538023 Time = 32.06 seconds
# Validation set: Average loss: 0.0632, f1 score : 0.9853, Accuracy: 8542/8670 (98.524%) , Time = 5.41 seconds
# Train Epoch: 113	Loss: 1.506270 Time = 32.05 seconds
# Validation set: Average loss: 0.0614, f1 score : 0.9849, Accuracy: 8539/8670 (98.489%) , Time = 5.47 seconds
# Train Epoch: 114	Loss: 1.001795 Time = 32.07 seconds
# Validation set: Average loss: 0.0681, f1 score : 0.9832, Accuracy: 8524/8670 (98.316%) , Time = 5.36 seconds
# Train Epoch: 115	Loss: 0.785602 Time = 31.96 seconds
# Validation set: Average loss: 0.0664, f1 score : 0.9840, Accuracy: 8531/8670 (98.397%) , Time = 5.36 seconds
# Train Epoch: 116	Loss: 1.546343 Time = 31.96 seconds
# Validation set: Average loss: 0.0629, f1 score : 0.9841, Accuracy: 8532/8670 (98.408%) , Time = 5.37 seconds
# Train Epoch: 117	Loss: 1.975120 Time = 32.01 seconds
# Validation set: Average loss: 0.0635, f1 score : 0.9840, Accuracy: 8531/8670 (98.397%) , Time = 5.51 seconds
# Train Epoch: 118	Loss: 1.844921 Time = 32.14 seconds
# Validation set: Average loss: 0.0651, f1 score : 0.9838, Accuracy: 8529/8670 (98.374%) , Time = 5.49 seconds
# Train Epoch: 119	Loss: 1.555068 Time = 32.09 seconds
# Validation set: Average loss: 0.0731, f1 score : 0.9833, Accuracy: 8525/8670 (98.328%) , Time = 5.47 seconds
# Train Epoch: 120	Loss: 0.515570 Time = 32.12 seconds
# Validation set: Average loss: 0.0647, f1 score : 0.9838, Accuracy: 8529/8670 (98.374%) , Time = 5.45 seconds
# Train Epoch: 121	Loss: 1.527671 Time = 32.04 seconds
# Validation set: Average loss: 0.0646, f1 score : 0.9839, Accuracy: 8530/8670 (98.385%) , Time = 5.40 seconds
# Train Epoch: 122	Loss: 1.526417 Time = 32.05 seconds
# Validation set: Average loss: 0.0646, f1 score : 0.9845, Accuracy: 8535/8670 (98.443%) , Time = 5.45 seconds
# Train Epoch: 123	Loss: 2.040952 Time = 31.88 seconds
# Validation set: Average loss: 0.0634, f1 score : 0.9847, Accuracy: 8537/8670 (98.466%) , Time = 5.37 seconds
# Train Epoch: 124	Loss: 1.642477 Time = 32.03 seconds
# Validation set: Average loss: 1.0372, f1 score : 0.7364, Accuracy: 6386/8670 (73.656%) , Time = 5.32 seconds
# Train Epoch: 125	Loss: 1.539792 Time = 31.95 seconds
# Validation set: Average loss: 0.0706, f1 score : 0.9838, Accuracy: 8529/8670 (98.374%) , Time = 5.27 seconds
# Train Epoch: 126	Loss: 2.028216 Time = 32.33 seconds
# Validation set: Average loss: 0.0721, f1 score : 0.9813, Accuracy: 8507/8670 (98.120%) , Time = 5.32 seconds
# Train Epoch: 127	Loss: 1.032472 Time = 32.02 seconds
# Validation set: Average loss: 0.0674, f1 score : 0.9831, Accuracy: 8523/8670 (98.304%) , Time = 5.27 seconds
# Train Epoch: 128	Loss: 0.772472 Time = 31.72 seconds
# Validation set: Average loss: 0.0707, f1 score : 0.9822, Accuracy: 8515/8670 (98.212%) , Time = 5.30 seconds
# Train Epoch: 129	Loss: 2.272881 Time = 31.68 seconds
# Validation set: Average loss: 0.0677, f1 score : 0.9835, Accuracy: 8526/8670 (98.339%) , Time = 5.31 seconds
# Train Epoch: 130	Loss: 0.787836 Time = 31.71 seconds
# Validation set: Average loss: 0.0712, f1 score : 0.9830, Accuracy: 8522/8670 (98.293%) , Time = 5.33 seconds
# Train Epoch: 131	Loss: 1.026906 Time = 31.81 seconds
# Validation set: Average loss: 0.0680, f1 score : 0.9840, Accuracy: 8531/8670 (98.397%) , Time = 5.25 seconds
# Train Epoch: 132	Loss: 2.280092 Time = 31.92 seconds
# Validation set: Average loss: 0.0670, f1 score : 0.9841, Accuracy: 8532/8670 (98.408%) , Time = 5.33 seconds
# Train Epoch: 133	Loss: 1.861795 Time = 32.00 seconds
# Validation set: Average loss: 0.0680, f1 score : 0.9843, Accuracy: 8533/8670 (98.420%) , Time = 5.38 seconds
# Train Epoch: 134	Loss: 1.298895 Time = 32.01 seconds
# Validation set: Average loss: 0.0656, f1 score : 0.9845, Accuracy: 8535/8670 (98.443%) , Time = 5.44 seconds
# Train Epoch: 135	Loss: 1.037681 Time = 32.03 seconds
# Validation set: Average loss: 0.1006, f1 score : 0.9776, Accuracy: 8475/8670 (97.751%) , Time = 5.58 seconds
# Train Epoch: 136	Loss: 1.486697 Time = 32.05 seconds
# Validation set: Average loss: 0.0630, f1 score : 0.9858, Accuracy: 8546/8670 (98.570%) , Time = 5.33 seconds
#
# Saved model to model_136.pth. You can run `python evaluate.py model_136.pth` to generate the Kaggle formatted csv file
# Train Epoch: 137	Loss: 1.842335 Time = 32.07 seconds
# Validation set: Average loss: 0.0672, f1 score : 0.9848, Accuracy: 8538/8670 (98.478%) , Time = 5.45 seconds
# Train Epoch: 138	Loss: 1.519752 Time = 31.91 seconds
# Validation set: Average loss: 0.0624, f1 score : 0.9849, Accuracy: 8539/8670 (98.489%) , Time = 5.34 seconds
# Train Epoch: 139	Loss: 2.323725 Time = 32.06 seconds
# Validation set: Average loss: 0.0702, f1 score : 0.9841, Accuracy: 8532/8670 (98.408%) , Time = 5.37 seconds
# Train Epoch: 140	Loss: 0.803695 Time = 31.91 seconds
# Validation set: Average loss: 0.0664, f1 score : 0.9855, Accuracy: 8544/8670 (98.547%) , Time = 5.29 seconds
# Train Epoch: 141	Loss: 1.271719 Time = 31.88 seconds
# Validation set: Average loss: 0.0616, f1 score : 0.9862, Accuracy: 8550/8670 (98.616%) , Time = 5.24 seconds
#
# Saved model to model_141.pth. You can run `python evaluate.py model_141.pth` to generate the Kaggle formatted csv file
# Train Epoch: 142	Loss: 2.583051 Time = 31.67 seconds
# Validation set: Average loss: 0.0664, f1 score : 0.9851, Accuracy: 8540/8670 (98.501%) , Time = 5.14 seconds
# Train Epoch: 143	Loss: 1.240360 Time = 31.61 seconds
# Validation set: Average loss: 0.0640, f1 score : 0.9851, Accuracy: 8540/8670 (98.501%) , Time = 5.28 seconds
# Train Epoch: 144	Loss: 1.301857 Time = 31.55 seconds
# Validation set: Average loss: 0.0626, f1 score : 0.9853, Accuracy: 8542/8670 (98.524%) , Time = 5.23 seconds
# Train Epoch: 145	Loss: 1.810958 Time = 31.60 seconds
# Validation set: Average loss: 0.0636, f1 score : 0.9845, Accuracy: 8535/8670 (98.443%) , Time = 5.21 seconds
# Train Epoch: 146	Loss: 1.796080 Time = 31.78 seconds
# Validation set: Average loss: 0.0630, f1 score : 0.9854, Accuracy: 8543/8670 (98.535%) , Time = 5.27 seconds
# Train Epoch: 147	Loss: 1.033518 Time = 31.78 seconds
# Validation set: Average loss: 0.0639, f1 score : 0.9845, Accuracy: 8535/8670 (98.443%) , Time = 5.36 seconds
# Train Epoch: 148	Loss: 1.532322 Time = 31.78 seconds
# Validation set: Average loss: 0.0638, f1 score : 0.9859, Accuracy: 8547/8670 (98.581%) , Time = 5.26 seconds
# Train Epoch: 149	Loss: 1.332288 Time = 31.68 seconds
# Validation set: Average loss: 0.0641, f1 score : 0.9851, Accuracy: 8540/8670 (98.501%) , Time = 5.18 seconds
# Train Epoch: 150	Loss: 1.265386 Time = 31.76 seconds
# Validation set: Average loss: 0.0634, f1 score : 0.9849, Accuracy: 8539/8670 (98.489%) , Time = 5.12 seconds
# Train Epoch: 151	Loss: 2.019765 Time = 31.56 seconds
# Validation set: Average loss: 0.3999, f1 score : 0.8989, Accuracy: 7793/8670 (89.885%) , Time = 5.23 seconds
# Train Epoch: 152	Loss: 2.605285 Time = 31.67 seconds
# Validation set: Average loss: 0.0759, f1 score : 0.9823, Accuracy: 8516/8670 (98.224%) , Time = 5.34 seconds
# Train Epoch: 153	Loss: 1.537070 Time = 31.66 seconds
# Validation set: Average loss: 0.0747, f1 score : 0.9820, Accuracy: 8513/8670 (98.189%) , Time = 5.34 seconds
# Train Epoch: 154	Loss: 1.275732 Time = 32.07 seconds
# Validation set: Average loss: 0.0701, f1 score : 0.9836, Accuracy: 8527/8670 (98.351%) , Time = 5.38 seconds
# Train Epoch: 155	Loss: 2.087095 Time = 31.86 seconds
# Validation set: Average loss: 0.0725, f1 score : 0.9831, Accuracy: 8523/8670 (98.304%) , Time = 5.32 seconds
# Train Epoch: 156	Loss: 1.749502 Time = 32.03 seconds
# Validation set: Average loss: 0.0680, f1 score : 0.9836, Accuracy: 8527/8670 (98.351%) , Time = 5.40 seconds
# Train Epoch: 157	Loss: 1.567947 Time = 32.03 seconds
# Validation set: Average loss: 0.0653, f1 score : 0.9848, Accuracy: 8538/8670 (98.478%) , Time = 5.35 seconds
# Train Epoch: 158	Loss: 1.751452 Time = 31.98 seconds
# Validation set: Average loss: 0.0672, f1 score : 0.9847, Accuracy: 8537/8670 (98.466%) , Time = 5.32 seconds
# Train Epoch: 159	Loss: 2.356356 Time = 31.96 seconds
# Validation set: Average loss: 0.0637, f1 score : 0.9851, Accuracy: 8540/8670 (98.501%) , Time = 5.33 seconds
# Train Epoch: 160	Loss: 1.006309 Time = 31.92 seconds
# Validation set: Average loss: 0.0676, f1 score : 0.9847, Accuracy: 8537/8670 (98.466%) , Time = 5.33 seconds
# Train Epoch: 161	Loss: 2.074988 Time = 31.69 seconds
# Validation set: Average loss: 0.0634, f1 score : 0.9856, Accuracy: 8545/8670 (98.558%) , Time = 5.14 seconds
# Train Epoch: 162	Loss: 1.546825 Time = 31.87 seconds
# Validation set: Average loss: 0.0680, f1 score : 0.9836, Accuracy: 8527/8670 (98.351%) , Time = 5.33 seconds
# Train Epoch: 163	Loss: 1.785375 Time = 31.93 seconds
# Validation set: Average loss: 0.0662, f1 score : 0.9844, Accuracy: 8534/8670 (98.431%) , Time = 5.29 seconds
# Train Epoch: 164	Loss: 2.058614 Time = 31.83 seconds
# Validation set: Average loss: 0.0669, f1 score : 0.9843, Accuracy: 8533/8670 (98.420%) , Time = 5.11 seconds
# Train Epoch: 165	Loss: 1.532287 Time = 31.58 seconds
# Validation set: Average loss: 0.0661, f1 score : 0.9843, Accuracy: 8533/8670 (98.420%) , Time = 5.17 seconds
# Train Epoch: 166	Loss: 1.294455 Time = 31.57 seconds
# Validation set: Average loss: 0.0686, f1 score : 0.9841, Accuracy: 8532/8670 (98.408%) , Time = 5.14 seconds
# Train Epoch: 167	Loss: 1.545711 Time = 31.59 seconds
# Validation set: Average loss: 0.0659, f1 score : 0.9837, Accuracy: 8528/8670 (98.362%) , Time = 5.17 seconds
# Train Epoch: 168	Loss: 2.109810 Time = 31.67 seconds
# Validation set: Average loss: 0.0668, f1 score : 0.9840, Accuracy: 8531/8670 (98.397%) , Time = 5.31 seconds
# Train Epoch: 169	Loss: 2.281863 Time = 31.65 seconds
# Validation set: Average loss: 0.0653, f1 score : 0.9840, Accuracy: 8531/8670 (98.397%) , Time = 5.27 seconds
# Train Epoch: 170	Loss: 1.286744 Time = 31.83 seconds
# Validation set: Average loss: 0.0647, f1 score : 0.9852, Accuracy: 8541/8670 (98.512%) , Time = 5.34 seconds
# Train Epoch: 171	Loss: 1.661911 Time = 31.88 seconds
# Validation set: Average loss: 0.1603, f1 score : 0.9638, Accuracy: 8355/8670 (96.367%) , Time = 5.09 seconds
# Train Epoch: 172	Loss: 1.790503 Time = 31.75 seconds
# Validation set: Average loss: 0.0640, f1 score : 0.9847, Accuracy: 8537/8670 (98.466%) , Time = 5.21 seconds
# Train Epoch: 173	Loss: 1.847279 Time = 31.62 seconds
# Validation set: Average loss: 0.0769, f1 score : 0.9815, Accuracy: 8509/8670 (98.143%) , Time = 5.23 seconds
# Train Epoch: 174	Loss: 1.525853 Time = 31.55 seconds
# Validation set: Average loss: 0.0586, f1 score : 0.9870, Accuracy: 8557/8670 (98.697%) , Time = 5.28 seconds
#
# Saved model to model_174.pth. You can run `python evaluate.py model_174.pth` to generate the Kaggle formatted csv file
# Train Epoch: 175	Loss: 2.023852 Time = 32.01 seconds
# Validation set: Average loss: 0.0648, f1 score : 0.9846, Accuracy: 8536/8670 (98.454%) , Time = 5.35 seconds
# Train Epoch: 176	Loss: 1.069992 Time = 31.94 seconds
# Validation set: Average loss: 0.0653, f1 score : 0.9849, Accuracy: 8539/8670 (98.489%) , Time = 5.31 seconds
# Train Epoch: 177	Loss: 1.486875 Time = 31.86 seconds
# Validation set: Average loss: 2.6888, f1 score : 0.5511, Accuracy: 4787/8670 (55.213%) , Time = 5.26 seconds
# Train Epoch: 178	Loss: 2.082631 Time = 31.94 seconds
# Validation set: Average loss: 0.0853, f1 score : 0.9801, Accuracy: 8497/8670 (98.005%) , Time = 5.30 seconds
# Train Epoch: 179	Loss: 2.041654 Time = 31.89 seconds
# Validation set: Average loss: 0.0848, f1 score : 0.9799, Accuracy: 8495/8670 (97.982%) , Time = 5.19 seconds
# Train Epoch: 180	Loss: 1.778307 Time = 31.63 seconds
# Validation set: Average loss: 0.0709, f1 score : 0.9836, Accuracy: 8527/8670 (98.351%) , Time = 5.17 seconds
# Train Epoch: 181	Loss: 1.031801 Time = 31.63 seconds
# Validation set: Average loss: 0.0881, f1 score : 0.9781, Accuracy: 8479/8670 (97.797%) , Time = 5.17 seconds
# Train Epoch: 182	Loss: 0.748854 Time = 31.60 seconds
# Validation set: Average loss: 0.0733, f1 score : 0.9830, Accuracy: 8522/8670 (98.293%) , Time = 5.28 seconds
# Train Epoch: 183	Loss: 1.555733 Time = 31.67 seconds
# Validation set: Average loss: 0.0675, f1 score : 0.9833, Accuracy: 8525/8670 (98.328%) , Time = 5.19 seconds
# Train Epoch: 184	Loss: 2.363005 Time = 31.82 seconds
# Validation set: Average loss: 0.0701, f1 score : 0.9832, Accuracy: 8524/8670 (98.316%) , Time = 5.26 seconds
# Train Epoch: 185	Loss: 2.534350 Time = 31.88 seconds
# Validation set: Average loss: 0.0691, f1 score : 0.9835, Accuracy: 8526/8670 (98.339%) , Time = 5.31 seconds
# Train Epoch: 186	Loss: 2.627177 Time = 31.95 seconds
# Validation set: Average loss: 0.0715, f1 score : 0.9838, Accuracy: 8529/8670 (98.374%) , Time = 5.35 seconds
# Train Epoch: 187	Loss: 1.789397 Time = 31.89 seconds
# Validation set: Average loss: 0.0630, f1 score : 0.9847, Accuracy: 8537/8670 (98.466%) , Time = 5.31 seconds
# Train Epoch: 188	Loss: 1.288677 Time = 31.99 seconds
# Validation set: Average loss: 0.0682, f1 score : 0.9837, Accuracy: 8528/8670 (98.362%) , Time = 5.31 seconds
# Train Epoch: 189	Loss: 2.069136 Time = 31.83 seconds
# Validation set: Average loss: 0.0744, f1 score : 0.9815, Accuracy: 8509/8670 (98.143%) , Time = 5.35 seconds
# Train Epoch: 190	Loss: 2.049467 Time = 31.90 seconds
# Validation set: Average loss: 0.0663, f1 score : 0.9844, Accuracy: 8534/8670 (98.431%) , Time = 5.29 seconds
# Train Epoch: 191	Loss: 2.490558 Time = 31.81 seconds
# Validation set: Average loss: 0.0661, f1 score : 0.9843, Accuracy: 8533/8670 (98.420%) , Time = 5.38 seconds
# Train Epoch: 192	Loss: 1.781515 Time = 32.00 seconds
# Validation set: Average loss: 0.0703, f1 score : 0.9844, Accuracy: 8534/8670 (98.431%) , Time = 5.29 seconds
# Train Epoch: 193	Loss: 1.874443 Time = 31.74 seconds
# Validation set: Average loss: 0.0615, f1 score : 0.9856, Accuracy: 8545/8670 (98.558%) , Time = 5.27 seconds
# Train Epoch: 194	Loss: 1.259298 Time = 31.78 seconds
# Validation set: Average loss: 0.0687, f1 score : 0.9831, Accuracy: 8523/8670 (98.304%) , Time = 5.31 seconds
# Train Epoch: 195	Loss: 0.511084 Time = 31.97 seconds
# Validation set: Average loss: 0.0670, f1 score : 0.9839, Accuracy: 8530/8670 (98.385%) , Time = 5.28 seconds
# Train Epoch: 196	Loss: 1.072741 Time = 31.92 seconds
# Validation set: Average loss: 0.0680, f1 score : 0.9841, Accuracy: 8532/8670 (98.408%) , Time = 5.29 seconds
# Train Epoch: 197	Loss: 1.788201 Time = 31.92 seconds
# Validation set: Average loss: 0.0605, f1 score : 0.9859, Accuracy: 8547/8670 (98.581%) , Time = 5.34 seconds
# Train Epoch: 198	Loss: 1.725914 Time = 31.95 seconds
# Validation set: Average loss: 0.0629, f1 score : 0.9846, Accuracy: 8536/8670 (98.454%) , Time = 5.27 seconds
# Train Epoch: 199	Loss: 2.038097 Time = 31.92 seconds
# Validation set: Average loss: 0.0601, f1 score : 0.9860, Accuracy: 8548/8670 (98.593%) , Time = 5.30 seconds
# Train Epoch: 200	Loss: 1.252533 Time = 32.00 seconds
# Validation set: Average loss: 0.0607, f1 score : 0.9855, Accuracy: 8544/8670 (98.547%) , Time = 5.32 seconds
# Train Epoch: 201	Loss: 1.300047 Time = 32.24 seconds
# Validation set: Average loss: 0.0652, f1 score : 0.9841, Accuracy: 8532/8670 (98.408%) , Time = 5.25 seconds
# Train Epoch: 202	Loss: 0.539140 Time = 31.82 seconds
# Validation set: Average loss: 0.0628, f1 score : 0.9858, Accuracy: 8546/8670 (98.570%) , Time = 5.24 seconds
# Train Epoch: 203	Loss: 1.334339 Time = 31.75 seconds
# Validation set: Average loss: 0.0618, f1 score : 0.9854, Accuracy: 8543/8670 (98.535%) , Time = 5.21 seconds
# Train Epoch: 204	Loss: 1.543973 Time = 31.82 seconds
# Validation set: Average loss: 0.0608, f1 score : 0.9856, Accuracy: 8545/8670 (98.558%) , Time = 5.28 seconds
# Train Epoch: 205	Loss: 1.602602 Time = 32.00 seconds
# Validation set: Average loss: 0.0663, f1 score : 0.9843, Accuracy: 8533/8670 (98.420%) , Time = 5.29 seconds
# Train Epoch: 206	Loss: 2.271853 Time = 32.04 seconds
# Validation set: Average loss: 0.0659, f1 score : 0.9845, Accuracy: 8535/8670 (98.443%) , Time = 5.28 seconds
# Train Epoch: 207	Loss: 2.294882 Time = 31.94 seconds
# Validation set: Average loss: 0.0621, f1 score : 0.9860, Accuracy: 8548/8670 (98.593%) , Time = 5.32 seconds
# Train Epoch: 208	Loss: 2.791589 Time = 31.98 seconds
# Validation set: Average loss: 0.0608, f1 score : 0.9860, Accuracy: 8548/8670 (98.593%) , Time = 5.35 seconds
# Train Epoch: 209	Loss: 1.859223 Time = 31.90 seconds
# Validation set: Average loss: 0.0586, f1 score : 0.9862, Accuracy: 8550/8670 (98.616%) , Time = 5.30 seconds
# Train Epoch: 210	Loss: 1.299737 Time = 32.02 seconds
# Validation set: Average loss: 0.0627, f1 score : 0.9849, Accuracy: 8539/8670 (98.489%) , Time = 5.37 seconds
# Train Epoch: 211	Loss: 0.744716 Time = 31.84 seconds
# Validation set: Average loss: 0.0636, f1 score : 0.9856, Accuracy: 8545/8670 (98.558%) , Time = 5.20 seconds
# Train Epoch: 212	Loss: 1.826201 Time = 31.79 seconds
# Validation set: Average loss: 0.0625, f1 score : 0.9851, Accuracy: 8540/8670 (98.501%) , Time = 5.21 seconds
# Train Epoch: 213	Loss: 1.561766 Time = 31.71 seconds
# Validation set: Average loss: 0.0637, f1 score : 0.9851, Accuracy: 8540/8670 (98.501%) , Time = 5.28 seconds
# Train Epoch: 214	Loss: 1.535019 Time = 32.04 seconds
# Validation set: Average loss: 0.0603, f1 score : 0.9859, Accuracy: 8547/8670 (98.581%) , Time = 5.34 seconds
# Train Epoch: 215	Loss: 1.575446 Time = 31.91 seconds
# Validation set: Average loss: 0.0608, f1 score : 0.9848, Accuracy: 8538/8670 (98.478%) , Time = 5.33 seconds
# Train Epoch: 216	Loss: 2.088661 Time = 32.00 seconds
# Validation set: Average loss: 0.0590, f1 score : 0.9862, Accuracy: 8550/8670 (98.616%) , Time = 5.35 seconds
# Train Epoch: 217	Loss: 1.053379 Time = 31.89 seconds
# Validation set: Average loss: 0.0621, f1 score : 0.9855, Accuracy: 8544/8670 (98.547%) , Time = 5.36 seconds
# Train Epoch: 218	Loss: 1.329053 Time = 32.00 seconds
# Validation set: Average loss: 0.0640, f1 score : 0.9844, Accuracy: 8534/8670 (98.431%) , Time = 5.36 seconds
# Train Epoch: 219	Loss: 1.481050 Time = 31.94 seconds
# Validation set: Average loss: 0.0646, f1 score : 0.9847, Accuracy: 8537/8670 (98.466%) , Time = 5.28 seconds
# Train Epoch: 220	Loss: 2.018681 Time = 32.04 seconds
# Validation set: Average loss: 0.0630, f1 score : 0.9854, Accuracy: 8543/8670 (98.535%) , Time = 5.30 seconds
# Train Epoch: 221	Loss: 2.042945 Time = 31.75 seconds
# Validation set: Average loss: 0.0599, f1 score : 0.9862, Accuracy: 8550/8670 (98.616%) , Time = 5.19 seconds
# Train Epoch: 222	Loss: 0.977843 Time = 31.70 seconds
# Validation set: Average loss: 0.0601, f1 score : 0.9856, Accuracy: 8545/8670 (98.558%) , Time = 5.22 seconds
# Train Epoch: 223	Loss: 1.033302 Time = 31.79 seconds
# Validation set: Average loss: 0.0615, f1 score : 0.9862, Accuracy: 8550/8670 (98.616%) , Time = 5.26 seconds
# Train Epoch: 224	Loss: 1.278023 Time = 31.95 seconds
# Validation set: Average loss: 0.0618, f1 score : 0.9858, Accuracy: 8546/8670 (98.570%) , Time = 5.30 seconds
# Train Epoch: 225	Loss: 1.319209 Time = 32.07 seconds
# Validation set: Average loss: 0.0653, f1 score : 0.9841, Accuracy: 8532/8670 (98.408%) , Time = 5.29 seconds
# Train Epoch: 226	Loss: 1.364659 Time = 31.93 seconds
# Validation set: Average loss: 0.0669, f1 score : 0.9849, Accuracy: 8539/8670 (98.489%) , Time = 5.31 seconds
# Train Epoch: 227	Loss: 1.553722 Time = 31.88 seconds
# Validation set: Average loss: 0.0643, f1 score : 0.9846, Accuracy: 8536/8670 (98.454%) , Time = 5.26 seconds
# Train Epoch: 228	Loss: 1.793149 Time = 31.95 seconds
# Validation set: Average loss: 0.0563, f1 score : 0.9867, Accuracy: 8554/8670 (98.662%) , Time = 5.32 seconds
# Train Epoch: 229	Loss: 2.060587 Time = 31.99 seconds
# Validation set: Average loss: 0.0632, f1 score : 0.9847, Accuracy: 8537/8670 (98.466%) , Time = 5.26 seconds
# Train Epoch: 230	Loss: 2.093589 Time = 32.10 seconds
# Validation set: Average loss: 0.0621, f1 score : 0.9846, Accuracy: 8536/8670 (98.454%) , Time = 5.33 seconds
# Train Epoch: 231	Loss: 1.038213 Time = 31.80 seconds
# Validation set: Average loss: 0.0599, f1 score : 0.9861, Accuracy: 8549/8670 (98.604%) , Time = 5.20 seconds
# Train Epoch: 232	Loss: 1.770197 Time = 31.77 seconds
# Validation set: Average loss: 0.0609, f1 score : 0.9855, Accuracy: 8544/8670 (98.547%) , Time = 5.29 seconds
# Train Epoch: 233	Loss: 1.515889 Time = 31.97 seconds
# Validation set: Average loss: 0.0610, f1 score : 0.9851, Accuracy: 8540/8670 (98.501%) , Time = 5.33 seconds
# Train Epoch: 234	Loss: 1.806839 Time = 31.90 seconds
# Validation set: Average loss: 0.0595, f1 score : 0.9855, Accuracy: 8544/8670 (98.547%) , Time = 5.32 seconds
# Train Epoch: 235	Loss: 1.798217 Time = 32.02 seconds
# Validation set: Average loss: 0.0636, f1 score : 0.9851, Accuracy: 8540/8670 (98.501%) , Time = 5.27 seconds
# Train Epoch: 236	Loss: 1.579766 Time = 31.84 seconds
# Validation set: Average loss: 0.0565, f1 score : 0.9866, Accuracy: 8553/8670 (98.651%) , Time = 5.30 seconds
# Train Epoch: 237	Loss: 1.266966 Time = 32.01 seconds
# Validation set: Average loss: 0.0603, f1 score : 0.9854, Accuracy: 8543/8670 (98.535%) , Time = 5.31 seconds
# Train Epoch: 238	Loss: 1.090916 Time = 31.78 seconds
# Validation set: Average loss: 0.0589, f1 score : 0.9861, Accuracy: 8549/8670 (98.604%) , Time = 5.23 seconds
# Train Epoch: 239	Loss: 2.083060 Time = 31.98 seconds
# Validation set: Average loss: 0.0622, f1 score : 0.9852, Accuracy: 8541/8670 (98.512%) , Time = 5.35 seconds
# Train Epoch: 240	Loss: 2.601318 Time = 31.98 seconds
# Validation set: Average loss: 0.0597, f1 score : 0.9859, Accuracy: 8547/8670 (98.581%) , Time = 5.25 seconds
# Train Epoch: 241	Loss: 2.349870 Time = 31.77 seconds
# Validation set: Average loss: 0.0625, f1 score : 0.9862, Accuracy: 8550/8670 (98.616%) , Time = 5.18 seconds
# Train Epoch: 242	Loss: 1.002854 Time = 32.17 seconds
# Validation set: Average loss: 0.0599, f1 score : 0.9853, Accuracy: 8542/8670 (98.524%) , Time = 5.38 seconds
# Train Epoch: 243	Loss: 1.810183 Time = 32.20 seconds
# Validation set: Average loss: 0.0605, f1 score : 0.9861, Accuracy: 8549/8670 (98.604%) , Time = 5.30 seconds
# Train Epoch: 244	Loss: 1.823894 Time = 31.95 seconds
# Validation set: Average loss: 0.0596, f1 score : 0.9861, Accuracy: 8549/8670 (98.604%) , Time = 5.32 seconds
# Train Epoch: 245	Loss: 1.275986 Time = 31.83 seconds
# Validation set: Average loss: 0.0600, f1 score : 0.9854, Accuracy: 8543/8670 (98.535%) , Time = 5.25 seconds
# Train Epoch: 246	Loss: 1.302626 Time = 32.02 seconds
# Validation set: Average loss: 0.0595, f1 score : 0.9844, Accuracy: 8534/8670 (98.431%) , Time = 5.31 seconds
# Train Epoch: 247	Loss: 1.054735 Time = 31.86 seconds
# Validation set: Average loss: 0.0617, f1 score : 0.9846, Accuracy: 8536/8670 (98.454%) , Time = 5.31 seconds
# Train Epoch: 248	Loss: 1.789816 Time = 32.05 seconds
# Validation set: Average loss: 0.0615, f1 score : 0.9849, Accuracy: 8539/8670 (98.489%) , Time = 5.28 seconds
# Train Epoch: 249	Loss: 1.271132 Time = 32.04 seconds
# Validation set: Average loss: 0.0606, f1 score : 0.9860, Accuracy: 8548/8670 (98.593%) , Time = 5.38 seconds
# Train Epoch: 250	Loss: 1.280180 Time = 32.13 seconds
# Validation set: Average loss: 0.0625, f1 score : 0.9855, Accuracy: 8544/8670 (98.547%) , Time = 5.27 seconds
# Train Epoch: 251	Loss: 1.300402 Time = 31.55 seconds
# Validation set: Average loss: 0.0569, f1 score : 0.9862, Accuracy: 8550/8670 (98.616%) , Time = 5.31 seconds
# Train Epoch: 252	Loss: 1.490263 Time = 31.88 seconds
# Validation set: Average loss: 0.0617, f1 score : 0.9849, Accuracy: 8539/8670 (98.489%) , Time = 5.30 seconds
# Train Epoch: 253	Loss: 1.518186 Time = 31.88 seconds
# Validation set: Average loss: 0.0602, f1 score : 0.9853, Accuracy: 8542/8670 (98.524%) , Time = 5.29 seconds
# Train Epoch: 254	Loss: 1.559733 Time = 31.94 seconds
# Validation set: Average loss: 0.0602, f1 score : 0.9858, Accuracy: 8546/8670 (98.570%) , Time = 5.25 seconds
# Train Epoch: 255	Loss: 1.783204 Time = 31.97 seconds
# Validation set: Average loss: 0.0573, f1 score : 0.9863, Accuracy: 8551/8670 (98.627%) , Time = 5.33 seconds
# Train Epoch: 256	Loss: 1.839121 Time = 32.12 seconds
# Validation set: Average loss: 0.0602, f1 score : 0.9862, Accuracy: 8550/8670 (98.616%) , Time = 5.38 seconds
# Train Epoch: 257	Loss: 1.839191 Time = 31.96 seconds
# Validation set: Average loss: 0.0590, f1 score : 0.9860, Accuracy: 8548/8670 (98.593%) , Time = 5.28 seconds
# Train Epoch: 258	Loss: 1.317390 Time = 31.87 seconds
# Validation set: Average loss: 0.0588, f1 score : 0.9868, Accuracy: 8555/8670 (98.674%) , Time = 5.27 seconds
# Train Epoch: 259	Loss: 1.312294 Time = 31.85 seconds
# Validation set: Average loss: 0.0582, f1 score : 0.9863, Accuracy: 8551/8670 (98.627%) , Time = 5.34 seconds
# Train Epoch: 260	Loss: 1.275977 Time = 31.93 seconds
# Validation set: Average loss: 0.0617, f1 score : 0.9854, Accuracy: 8543/8670 (98.535%) , Time = 5.25 seconds
# Train Epoch: 261	Loss: 1.517237 Time = 31.90 seconds
# Validation set: Average loss: 0.0654, f1 score : 0.9853, Accuracy: 8542/8670 (98.524%) , Time = 5.30 seconds
# Train Epoch: 262	Loss: 1.320368 Time = 31.90 seconds
# Validation set: Average loss: 0.0626, f1 score : 0.9848, Accuracy: 8538/8670 (98.478%) , Time = 5.27 seconds
# Train Epoch: 263	Loss: 1.283280 Time = 32.04 seconds
# Validation set: Average loss: 0.0563, f1 score : 0.9874, Accuracy: 8560/8670 (98.731%) , Time = 5.35 seconds
#
# Saved model to model_263.pth. You can run `python evaluate.py model_263.pth` to generate the Kaggle formatted csv file
# Train Epoch: 264	Loss: 1.571793 Time = 31.92 seconds
# Validation set: Average loss: 0.0596, f1 score : 0.9851, Accuracy: 8540/8670 (98.501%) , Time = 5.33 seconds
# Train Epoch: 265	Loss: 1.798333 Time = 31.55 seconds
# Validation set: Average loss: 0.0595, f1 score : 0.9861, Accuracy: 8549/8670 (98.604%) , Time = 5.25 seconds
# Train Epoch: 266	Loss: 0.997930 Time = 31.88 seconds
# Validation set: Average loss: 0.0603, f1 score : 0.9853, Accuracy: 8542/8670 (98.524%) , Time = 5.28 seconds
# Train Epoch: 267	Loss: 1.539589 Time = 31.89 seconds
# Validation set: Average loss: 0.0588, f1 score : 0.9852, Accuracy: 8541/8670 (98.512%) , Time = 5.33 seconds
# Train Epoch: 268	Loss: 1.498788 Time = 31.76 seconds
# Validation set: Average loss: 0.0595, f1 score : 0.9862, Accuracy: 8550/8670 (98.616%) , Time = 5.30 seconds
# Train Epoch: 269	Loss: 1.037584 Time = 31.91 seconds
# Validation set: Average loss: 0.0577, f1 score : 0.9863, Accuracy: 8551/8670 (98.627%) , Time = 5.21 seconds
# Train Epoch: 270	Loss: 0.508420 Time = 32.02 seconds
# Validation set: Average loss: 0.0612, f1 score : 0.9854, Accuracy: 8543/8670 (98.535%) , Time = 5.27 seconds
# Train Epoch: 271	Loss: 1.551128 Time = 31.56 seconds
# Validation set: Average loss: 0.0610, f1 score : 0.9866, Accuracy: 8553/8670 (98.651%) , Time = 5.28 seconds
# Train Epoch: 272	Loss: 2.042943 Time = 31.56 seconds
# Validation set: Average loss: 0.0578, f1 score : 0.9860, Accuracy: 8548/8670 (98.593%) , Time = 5.30 seconds
# Train Epoch: 273	Loss: 1.612449 Time = 31.64 seconds
# Validation set: Average loss: 0.0560, f1 score : 0.9863, Accuracy: 8551/8670 (98.627%) , Time = 5.18 seconds
# Train Epoch: 274	Loss: 1.308899 Time = 31.78 seconds
# Validation set: Average loss: 0.0574, f1 score : 0.9863, Accuracy: 8551/8670 (98.627%) , Time = 5.23 seconds
# Train Epoch: 275	Loss: 2.047508 Time = 31.74 seconds
# Validation set: Average loss: 0.0567, f1 score : 0.9868, Accuracy: 8555/8670 (98.674%) , Time = 5.26 seconds
# Train Epoch: 276	Loss: 1.509356 Time = 31.79 seconds
# Validation set: Average loss: 0.0582, f1 score : 0.9860, Accuracy: 8548/8670 (98.593%) , Time = 5.30 seconds
# Train Epoch: 277	Loss: 1.753872 Time = 31.87 seconds
# Validation set: Average loss: 0.0588, f1 score : 0.9856, Accuracy: 8545/8670 (98.558%) , Time = 5.28 seconds
# Train Epoch: 278	Loss: 1.816954 Time = 31.91 seconds
# Validation set: Average loss: 0.0617, f1 score : 0.9855, Accuracy: 8544/8670 (98.547%) , Time = 5.22 seconds
# Train Epoch: 279	Loss: 1.524273 Time = 31.83 seconds
# Validation set: Average loss: 0.0581, f1 score : 0.9871, Accuracy: 8558/8670 (98.708%) , Time = 5.40 seconds
# Train Epoch: 280	Loss: 1.504394 Time = 31.96 seconds
# Validation set: Average loss: 0.0585, f1 score : 0.9858, Accuracy: 8546/8670 (98.570%) , Time = 5.33 seconds
# Train Epoch: 281	Loss: 1.266086 Time = 31.84 seconds
# Validation set: Average loss: 0.0599, f1 score : 0.9848, Accuracy: 8538/8670 (98.478%) , Time = 5.30 seconds
# Train Epoch: 282	Loss: 1.510349 Time = 31.93 seconds
# Validation set: Average loss: 0.0576, f1 score : 0.9864, Accuracy: 8552/8670 (98.639%) , Time = 5.31 seconds
# Train Epoch: 283	Loss: 1.566459 Time = 32.21 seconds
# Validation set: Average loss: 0.0566, f1 score : 0.9869, Accuracy: 8556/8670 (98.685%) , Time = 5.22 seconds
# Train Epoch: 284	Loss: 1.519650 Time = 31.48 seconds
# Validation set: Average loss: 0.0563, f1 score : 0.9855, Accuracy: 8544/8670 (98.547%) , Time = 5.24 seconds
# Train Epoch: 285	Loss: 1.234408 Time = 31.69 seconds
# Validation set: Average loss: 0.0554, f1 score : 0.9864, Accuracy: 8552/8670 (98.639%) , Time = 5.22 seconds
# Train Epoch: 286	Loss: 1.279903 Time = 31.52 seconds
# Validation set: Average loss: 0.0580, f1 score : 0.9864, Accuracy: 8552/8670 (98.639%) , Time = 5.14 seconds
# Train Epoch: 287	Loss: 1.555705 Time = 31.83 seconds
# Validation set: Average loss: 0.0577, f1 score : 0.9864, Accuracy: 8552/8670 (98.639%) , Time = 5.43 seconds
# Train Epoch: 288	Loss: 2.062027 Time = 31.78 seconds
# Validation set: Average loss: 0.0582, f1 score : 0.9863, Accuracy: 8551/8670 (98.627%) , Time = 5.31 seconds
# Train Epoch: 289	Loss: 1.797893 Time = 31.89 seconds
# Validation set: Average loss: 0.0579, f1 score : 0.9864, Accuracy: 8552/8670 (98.639%) , Time = 5.34 seconds
# Train Epoch: 290	Loss: 1.813647 Time = 31.98 seconds
# Validation set: Average loss: 0.0553, f1 score : 0.9870, Accuracy: 8557/8670 (98.697%) , Time = 5.35 seconds
# Train Epoch: 291	Loss: 2.028495 Time = 31.97 seconds
# Validation set: Average loss: 0.0589, f1 score : 0.9862, Accuracy: 8550/8670 (98.616%) , Time = 5.25 seconds
# Train Epoch: 292	Loss: 2.800092 Time = 31.91 seconds
# Validation set: Average loss: 0.0590, f1 score : 0.9853, Accuracy: 8542/8670 (98.524%) , Time = 5.34 seconds
# Train Epoch: 293	Loss: 1.306200 Time = 32.04 seconds
# Validation set: Average loss: 0.0587, f1 score : 0.9859, Accuracy: 8547/8670 (98.581%) , Time = 5.35 seconds
# Train Epoch: 294	Loss: 2.346762 Time = 31.96 seconds
# Validation set: Average loss: 0.0576, f1 score : 0.9862, Accuracy: 8550/8670 (98.616%) , Time = 5.31 seconds
# Train Epoch: 295	Loss: 1.757358 Time = 31.89 seconds
# Validation set: Average loss: 0.0606, f1 score : 0.9862, Accuracy: 8550/8670 (98.616%) , Time = 5.34 seconds
# Train Epoch: 296	Loss: 1.297067 Time = 32.04 seconds
# Validation set: Average loss: 0.0586, f1 score : 0.9860, Accuracy: 8548/8670 (98.593%) , Time = 5.38 seconds
# Train Epoch: 297	Loss: 1.249575 Time = 31.92 seconds
# Validation set: Average loss: 0.0548, f1 score : 0.9866, Accuracy: 8553/8670 (98.651%) , Time = 5.29 seconds
# Train Epoch: 298	Loss: 2.506764 Time = 31.88 seconds
# Validation set: Average loss: 0.0553, f1 score : 0.9866, Accuracy: 8553/8670 (98.651%) , Time = 5.33 seconds
# Train Epoch: 299	Loss: 1.514265 Time = 31.91 seconds
# Validation set: Average loss: 0.0573, f1 score : 0.9869, Accuracy: 8556/8670 (98.685%) , Time = 5.45 seconds

# %%
# Print confusion matrix

def plot_confusion_matrix(labels, pred_labels, classes):
    
    fig = plt.figure(figsize = (20, 20));
    ax = fig.add_subplot(1, 1, 1);
    cm = confusion_matrix(labels, pred_labels);
    cm = ConfusionMatrixDisplay(cm, display_labels = classes);
    cm.plot(values_format = 'd', cmap = 'Blues', ax = ax)
    plt.xticks(rotation = 20)
    
labels_arr = range(0, nclasses)
# plot_confusion_matrix(labels_list, y_pred_list, labels_arr)

# %%
# Load the saved model

model = Net()
model.load_state_dict(torch.load(model_file)) # 'model_35.pth'
model = model.cuda()

# model = Net()
# model.load_state_dict(torch.load('model_35.pth')) # 'model_35.pth'
# model = model.cuda()

# %%
test_answer = pd.read_csv('Test_Label.csv')
test_answer["pred_class"] = -1

num = range(nclasses)
labels = []
for i in num:
    labels.append(str(i))
labels = sorted(labels)
for i in num:
    labels[i] = int(labels[i])


test_transforms = transforms.Compose([
    transforms.Resize([48, 48]),
    transforms.ToTensor(),
    transforms.Normalize([meanR, meanG, meanB], [stdR, stdG, stdB])
])


# Perform classification

y_pred_list = []
corr_classified = 0
numExamples = len(test_answer)

##
labels_list = []



with torch.no_grad():
    model.eval()
    for f_name in test_answer["Filename"]:
        image = Image.open(f"Test//{f_name}")

        image = test_transforms(image)
        image = torch.unsqueeze(image, 0)
        # image = Variable(image)
        image = image.to(device)

        y_test_pred = model(image)
        y_pred_tags = y_test_pred.data.max(1, keepdim=True)[1]
        y_pred_tags = y_pred_tags.cpu().numpy()
        # print(y_pred_tags)

        y_pred = y_pred_tags[0][0]
        y_pred = labels[y_pred]
        
        y_pred_list.append(y_pred)

        # test_answer.loc[test_answer[test_answer["Filename"] == f_name].index, "pred_class"] = y_pred
        if test_answer[test_answer["Filename"] == f_name]["ClassId"].values[0] == y_pred:
            corr_classified += 1

        # i += 1

print("Number of correctly classified images = %d" % corr_classified)
print("Number of incorrectly classified images = %d" % (numExamples - corr_classified))
print("Final accuracy = %f" % (corr_classified / numExamples))

# Print classification report
print(classification_report(test_answer.ClassId, y_pred_list))

plot_confusion_matrix(test_answer.ClassId, y_pred_list, labels_arr)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"
# Number of correctly classified images = 8560
# Number of incorrectly classified images = 110
# Final accuracy = 0.987313
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        60
#            1       0.99      1.00      0.99       420
#            2       0.99      1.00      1.00       420
#            3       1.00      0.98      0.99       420
#            4       1.00      0.99      0.99       420
#            5       0.95      0.99      0.97       420
#            6       1.00      0.80      0.89        60
#            7       1.00      1.00      1.00       420
#            8       1.00      1.00      1.00       420
#            9       0.99      1.00      0.99       420
#           10       1.00      1.00      1.00       420
#           11       0.98      1.00      0.99       420
#           12       0.98      1.00      0.99       420
#           13       1.00      1.00      1.00       420
#           14       1.00      1.00      1.00       210
#           15       0.98      1.00      0.99       210
#           16       1.00      1.00      1.00        60
#           17       1.00      1.00      1.00       210
#           18       0.96      0.99      0.97       210
#           19       1.00      1.00      1.00        60
#           20       0.88      1.00      0.94        60
#           21       1.00      1.00      1.00        60
#           22       1.00      1.00      1.00        60
#           23       1.00      0.95      0.97        60
#           24       1.00      0.95      0.97        60
#           25       0.99      0.99      0.99       420
#           26       0.90      0.93      0.92        60
#           27       0.94      0.83      0.88        60
#           28       1.00      1.00      1.00        60
#           29       0.95      1.00      0.98        60
#           30       0.87      0.67      0.75        60
#           31       0.97      1.00      0.98       210
#           32       1.00      1.00      1.00        60
#           33       1.00      1.00      1.00       210
#           34       0.98      1.00      0.99        60
#           35       0.99      0.99      0.99       210
#           36       1.00      1.00      1.00        60
#           37       0.98      1.00      0.99        60
#           38       1.00      0.99      0.99       420
#           39       1.00      0.97      0.98        60
#           40       1.00      0.88      0.94        60
#           41       1.00      0.90      0.95        60
#           42       1.00      1.00      1.00        60
#
#     accuracy                           0.99      8670
#    macro avg       0.98      0.97      0.98      8670
# weighted avg       0.99      0.99      0.99      8670

# %% [markdown]
# # AlexnetTS

# %%
# # Function to count the number of parameters in the model

# def count_parameters(model):
#     return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
# import torch.nn as nn

# class AlexnetTS(nn.Module):
#     def __init__(self, output_dim):
#         super().__init__()
        
#         self.features = nn.Sequential(
#             nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, stride=2, padding=1),
#             nn.MaxPool2d(kernel_size=2),
#             nn.ReLU(inplace=True),
            
#             nn.Conv2d(in_channels=64, out_channels=192, kernel_size=3, padding=1),
#             nn.MaxPool2d(kernel_size=2),
#             nn.ReLU(inplace=True),
            
#             nn.Conv2d(in_channels=192, out_channels=384, kernel_size=3, padding=1),
#             nn.ReLU(inplace=True),
            
#             nn.Conv2d(in_channels=384, out_channels=256, kernel_size=3, padding=1),
#             nn.ReLU(inplace=True),
            
#             nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
#             nn.MaxPool2d(kernel_size=2),
#             nn.ReLU(inplace=True),
#             )
        
#         self.classifier = nn.Sequential(
#             nn.Dropout(0.5),
#             nn.Linear(256*7*7, 1000),
#             nn.ReLU(inplace=True),
            
#             nn.Dropout(0.5),
#             nn.Linear(in_features=1000, out_features=256),
#             nn.ReLU(inplace=True),
            
#             nn.Linear(256, output_dim)
#             )
        
#     def forward(self, x):
#         x = self.features(x)
#         h = x.view(x.shape[0], -1)
#         x = self.classifier(h)
#         return x, h

# %%
# # Initialize the model
# # The model is defined in the class AlexnetTS in the file class_alexnetTS.py

# model = AlexnetTS(numClasses)
# print(f'The model has {count_parameters(model):,} trainable parameters')

# # Define optimizer and criterion functions

# optimizer = optim.Adam(model.parameters(), lr=learning_rate)
# criterion = nn.CrossEntropyLoss()

# # If CUDA is available, convert model and loss to cuda variables

# if torch.cuda.is_available():
#     model = model.cuda()
#     criterion = criterion.cuda()

# # Print model
# print(model)

# # Print summary of the model for the given dimension of the image
# print(summary(model, (3, 48, 48))) 

# # Print model's state dict
# print("Model's state dict:")
# for param_tensor in model.state_dict():
#     print(param_tensor, "\t", model.state_dict()[param_tensor].size())
# print("")

# # Print optimizer details

# print("Optimizer details:")
# print(optimizer)
# print("")

# %%
# # Function to calculate accuracy

# def calculate_accuracy(y_pred, y):
#     top_pred = y_pred.argmax(1, keepdim = True)
#     correct = top_pred.eq(y.view_as(top_pred)).sum()
#     acc = correct.float() / y.shape[0]
#     return acc

# %%
# # Function to perform training of the model

# def train(model, loader, opt, criterion):
#     epoch_loss = 0
#     epoch_acc = 0
    
#     # Train the model
#     model.train()
    
#     for (images, labels) in loader:
#         images = images.cuda()
#         labels = labels.cuda()
#         # labels = labels.cuda().type(torch.LongTensor)
        
#         # Training pass
#         opt.zero_grad()
        
#         output, _ = model(images)
#         loss = criterion(output, labels)
        
#         # Backpropagation
#         loss.backward()
        
#         # Calculate accuracy
#         acc = calculate_accuracy(output, labels)
        
#         # Optimizing weights
#         opt.step()
        
#         epoch_loss += loss.item()
#         epoch_acc += acc.item()
        
#     return epoch_loss / len(loader), epoch_acc / len(loader)

# %%
# # Function to perform evaluation on the trained model

# def evaluate(model, loader, opt, criterion):
#     epoch_loss = 0
#     epoch_acc = 0
    
#     # Evaluate the model
#     model.eval()
    
#     with torch.no_grad():
#         for (images, labels) in loader:
#             images = images.cuda()
#             labels = labels.cuda()
            
#             # Run predictions
#             output, _ = model(images)
#             loss = criterion(output, labels)
            
#             # Calculate accuracy
#             acc = calculate_accuracy(output, labels)
            
#             epoch_loss += loss.item()
#             epoch_acc += acc.item()
    
#     return epoch_loss / len(loader), epoch_acc / len(loader)

# %%
# # Perform training
# local_epoch = 50
# # List to save training and val loss and accuracies
# # train_loss_list = [0]*EPOCHS
# # train_acc_list = [0]*EPOCHS
# # val_loss_list = [0]*EPOCHS
# # val_acc_list = [0]*EPOCHS
# train_loss_list = [0]*local_epoch
# train_acc_list = [0]*local_epoch
# val_loss_list = [0]*local_epoch
# val_acc_list = [0]*local_epoch

# # for epoch in range(EPOCHS):
# for epoch in range(local_epoch):
#     print("Epoch-%d: " % (epoch))

#     train_start_time = time.monotonic()
#     # train_loss, train_acc = train(model, answer_loader, optimizer, criterion)
#     # train_loss, train_acc = train(model, train_all_loader, optimizer, criterion)
#     train_loss, train_acc = train(model, train_aug_loader, optimizer, criterion)
#     train_end_time = time.monotonic()

#     val_start_time = time.monotonic()
#     # val_loss, val_acc = evaluate(model, val_loader, optimizer, criterion) # val data
#     val_loss, val_acc = evaluate(model, answer_loader, optimizer, criterion) # answer data
#     val_end_time = time.monotonic()
    
#     train_loss_list[epoch] = train_loss
#     train_acc_list[epoch] = train_acc
#     val_loss_list[epoch] = val_loss
#     val_acc_list[epoch] = val_acc
    
#     print("Training: Loss = %.4f, Accuracy = %.4f, Time = %.2f seconds" % (train_loss, train_acc, train_end_time - train_start_time))
#     print("Validation: Loss = %.4f, Accuracy = %.4f, Time = %.2f seconds" % (val_loss, val_acc, val_end_time - val_start_time))
#     print("")

# %%
# # Saving the model

# # Create folder to save model
# MODEL_FOLDER = "./Model"
# if not os.path.isdir(MODEL_FOLDER):
#     os.mkdir(MODEL_FOLDER)
    
# PATH_TO_MODEL = MODEL_FOLDER + "/pytorch_classification_alexnetTS.pth"
# if os.path.exists(PATH_TO_MODEL):
#     os.remove(PATH_TO_MODEL)
# torch.save(model.state_dict(), PATH_TO_MODEL)

# print("Model saved at %s" %(PATH_TO_MODEL))

# %%
# # Plot loss and accuracies for training and validation data

# _, axs = plt.subplots(1, 2, figsize=(15, 5))

# # Loss plot
# axs[0].plot(train_loss_list, label="train")
# axs[0].plot(val_loss_list, label="val")
# axs[0].set_title("Plot - Loss")
# axs[0].set_xlabel("Epochs")
# axs[0].set_ylabel("Loss")
# legend = axs[0].legend(loc='upper right', shadow=False)

# # Accuracy plot
# axs[1].plot(train_acc_list, label="train")
# axs[1].plot(val_acc_list, label="val")
# axs[1].set_title("Plot - Accuracy")
# axs[1].set_xlabel("Epochs")
# axs[1].set_ylabel("Accuracy")
# legend = axs[1].legend(loc='center right', shadow=True)

# %%
# test_answer = pd.read_csv('Test_Label.csv')
# test_answer["pred_class"] = -1

# num = range(numClasses)
# labels = []
# for i in num:
#     labels.append(str(i))
# labels = sorted(labels)
# for i in num:
#     labels[i] = int(labels[i])

# # Perform classification
# # test_transforms = transforms.Compose([
# #     transforms.Resize([112, 112]),
# #     transforms.ToTensor()
# #     ])
# test_transforms = transforms.Compose([
#     transforms.Resize([48, 48]),
#     transforms.ToTensor(),
#     # transforms.Normalize(mean=1, std=0.5)
#     ])
        
# y_pred_list = []
# corr_classified = 0
# numExamples = len(test_answer)

# ##
# labels_list = []

# with torch.no_grad():
#     model.eval()
#     for f_name in test_answer["Filename"]:
#         image = Image.open(f"Test//{f_name}")

#         image = test_transforms(image)
#         image = torch.unsqueeze(image, 0)
#         image = image.cuda()

#         y_test_pred = model(image)

#         y_pred_softmax = torch.log_softmax(y_test_pred[0], dim=1)
#         _, y_pred_tags = torch.max(y_pred_softmax, dim=1)
#         y_pred_tags = y_pred_tags.cpu().numpy()

#         y_pred = y_pred_tags[0]
#         y_pred = labels[y_pred]
        
#         y_pred_list.append(y_pred)

#         test_answer.loc[test_answer[test_answer["Filename"] == f_name].index, "pred_class"] = y_pred
#         if test_answer[test_answer["Filename"] == f_name]["ClassId"].values[0] == y_pred:
#             corr_classified += 1

#         # i += 1

# print("Number of correctly classified images = %d" % corr_classified)
# print("Number of incorrectly classified images = %d" % (numExamples - corr_classified))
# print("Final accuracy = %f" % (corr_classified / numExamples))

# # Print classification report
# print(classification_report(test_answer.ClassId, test_answer.pred_class))

# # plot_confusion_matrix(test_answer.ClassId, test_answer.pred_class, labels_arr)

# %%
# Number of correctly classified images = 8452
# Number of incorrectly classified images = 218
# Final accuracy = 0.974856
#               precision    recall  f1-score   support

#            0       1.00      1.00      1.00        60
#            1       0.99      0.99      0.99       420
#            2       0.97      0.97      0.97       420
#            3       0.96      0.99      0.97       420
#            4       1.00      0.98      0.99       420
#            5       0.98      0.97      0.97       420
#            6       1.00      0.87      0.93        60
#            7       0.99      1.00      1.00       420
#            8       1.00      0.99      0.99       420
#            9       1.00      1.00      1.00       420
#           10       1.00      0.99      1.00       420
#           11       0.94      0.99      0.97       420
#           12       0.99      0.98      0.99       420
#           13       0.99      0.99      0.99       420
#           14       1.00      1.00      1.00       210
#           15       0.99      0.99      0.99       210
#           16       1.00      1.00      1.00        60
#           17       1.00      1.00      1.00       210
#           18       0.98      0.87      0.92       210
#           19       0.98      1.00      0.99        60
#           20       0.92      0.98      0.95        60
#           21       0.98      0.75      0.85        60
#           22       1.00      0.98      0.99        60
#           23       1.00      0.80      0.89        60
#           24       0.97      0.95      0.96        60
#           25       0.99      0.98      0.98       420
#           26       1.00      0.92      0.96        60
#           27       0.79      0.55      0.65        60
#           28       0.78      0.98      0.87        60
#           29       0.88      1.00      0.94        60
#           30       0.61      0.58      0.60        60
#           31       0.90      0.99      0.94       210
#           32       0.83      1.00      0.91        60
#           33       0.99      0.99      0.99       210
#           34       1.00      1.00      1.00        60
#           35       1.00      1.00      1.00       210
#           36       0.98      1.00      0.99        60
#           37       1.00      1.00      1.00        60
#           38       1.00      0.99      0.99       420
#           39       0.94      0.98      0.96        60
#           40       1.00      0.97      0.98        60
#           41       0.79      0.93      0.85        60
#           42       1.00      1.00      1.00        60

#     accuracy                           0.97      8670
#    macro avg       0.96      0.95      0.95      8670
# weighted avg       0.98      0.97      0.97      8670

# %%
# test_answer = pd.read_csv('Test_Label.csv')
# test_answer["pred_class"] = -1

# num = range(numClasses)
# labels = []
# for i in num:
#     labels.append(str(i))
# labels = sorted(labels)
# for i in num:
#     labels[i] = int(labels[i])

# # Perform classification
# test_transforms = transforms.Compose([
#     transforms.Resize([48, 48]),
#     transforms.ToTensor(),
#     # transforms.Normalize(mean=1, std=0.5)
#     ])
        
# y_pred_list = []
# corr_classified = 0
# numExamples = len(test_answer)

# ##
# labels_list = []
# wronng_list = []
# with torch.no_grad():
#     model.eval()
#     for f_name in test_answer["Filename"]:
#         image = Image.open(f"Test//{f_name}")

#         image = test_transforms(image)
#         image = torch.unsqueeze(image, 0)
#         image = image.cuda()

#         y_test_pred = model(image)

#         y_pred_softmax = torch.log_softmax(y_test_pred[0], dim=1)
#         _, y_pred_tags = torch.max(y_pred_softmax, dim=1)
#         y_pred_tags = y_pred_tags.cpu().numpy()

#         y_pred = y_pred_tags[0]
#         y_pred = labels[y_pred]
        
#         y_pred_list.append(y_pred)

#         test_answer.loc[test_answer[test_answer["Filename"] == f_name].index, "pred_class"] = y_pred
#         if test_answer[test_answer["Filename"] == f_name]["ClassId"].values[0] == y_pred:
#             corr_classified += 1
#         else : 
#           wronng_list.append([f_name,test_answer[test_answer["Filename"] == f_name]["ClassId"].values[0], y_pred])
#         # i += 1

# print("Number of correctly classified images = %d" % corr_classified)
# print("Number of incorrectly classified images = %d" % (numExamples - corr_classified))
# print("Final accuracy = %f" % (corr_classified / numExamples))

# # Print classification report
# print(classification_report(test_answer.ClassId, test_answer.pred_class))

# # plot_confusion_matrix(test_answer.ClassId, test_answer.pred_class, labels_arr)

# %%
# df = pd.DataFrame(wronng_list) ## 데이터프래임 생성
# df.to_csv('wronng_list.csv',index=False) ## 구분자를 탭으로 하여 저장. 인덱스칼럼은 저장 안함.

# %%
# # Print confusion matrix

# def plot_confusion_matrix(labels, pred_labels, classes):
    
#     fig = plt.figure(figsize = (20, 20));
#     ax = fig.add_subplot(1, 1, 1);
#     # print(labels)
#     # print(pred_labels)
#     cm = confusion_matrix(labels, pred_labels);
#     cm = ConfusionMatrixDisplay(cm, display_labels = classes);
#     cm.plot(values_format = 'd', cmap = 'Blues', ax = ax)
#     plt.xticks(rotation = 20)
    
# labels_arr = range(0, numClasses)
# # plot_confusion_matrix(test_answer.ClassId, test_answer.pred_class, labels_arr)
# plot_confusion_matrix(test_answer.ClassId, y_pred_list, labels_arr)

# %% [markdown]
# # test using val_data

# %%
# val_data.dataset

# %%
# # Load the saved model

# model = AlexnetTS(numClasses)
# model.load_state_dict(torch.load(PATH_TO_MODEL))
# model = model.cuda()

# %%
# # Perform classification

# y_pred_list = []
# corr_classified = 0
# # numExamples = len(val_data)
# numExamples = len(val_data)

# ##
# labels_list = []

# with torch.no_grad():
#     model.eval()

#     # i = 0

#     for image, label_true in data.DataLoader(val_data, shuffle=True, batch_size = 1): # shuffle = False when test
#         labels_list.append(label_true.cpu().numpy()[0])
#         image = image.cuda()

#         y_test_pred = model(image)

#         y_pred_softmax = torch.log_softmax(y_test_pred[0], dim=1)
#         _, y_pred_tags = torch.max(y_pred_softmax, dim=1)
#         y_pred_tags = y_pred_tags.cpu().numpy()

#         y_pred_list.append(y_pred_tags[0])
#         if label_true == y_pred_tags[0]:
#             corr_classified += 1

#         # i += 1

# print("Number of correctly classified images = %d" % corr_classified)
# print("Number of incorrectly classified images = %d" % (numExamples - corr_classified))
# print("Final accuracy = %f" % (corr_classified / numExamples))

# %%
# # Print classification report

# print(classification_report(labels_list, y_pred_list))

# %%
# # Print confusion matrix

# def plot_confusion_matrix(labels, pred_labels, classes):
    
#     fig = plt.figure(figsize = (20, 20));
#     ax = fig.add_subplot(1, 1, 1);
#     cm = confusion_matrix(labels, pred_labels);
#     cm = ConfusionMatrixDisplay(cm, display_labels = classes);
#     cm.plot(values_format = 'd', cmap = 'Blues', ax = ax)
#     plt.xticks(rotation = 20)
    
# labels_arr = range(0, numClasses)
# plot_confusion_matrix(labels_list, y_pred_list, labels_arr)
